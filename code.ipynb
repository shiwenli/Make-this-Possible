# %%
import numpy as np
import scipy as sp

# %%
f= open('voc', 'r')
voc = f.read().strip().split("\n")
# Out:
# 6806

# %%
def parse_vocabulary(vocab):
    type_to_index = {}
    index_to_type = {}
    for word in set(vocab):
        index_to_type[len(index_to_type)] = word
        type_to_index[word] = len(type_to_index)        
    return (type_to_index, index_to_type)

# %%
type_to_index = parse_vocabulary(voc)[0]
index_to_type = parse_vocabulary(voc)[1]

# %%
ff = open('doc', 'r')
doc = ff.read().strip().split("\n")
# Out:
# 2221

# %%
def parse_data(corpus):
        word_ids = [];
        word_cts = [];
        
        for document_line in corpus:
            document_word_dict = {}
            for token in document_line.split():
                if token not in type_to_index:
                    continue
                
                type_id = type_to_index[token]
                if type_id not in document_word_dict:
                    document_word_dict[type_id] = 0
                document_word_dict[type_id] += 1
            
            word_ids.append(np.array(list(document_word_dict.keys())))
            word_cts.append(np.array(list(document_word_dict.values()))[numpy.newaxis, :])
        
        return (word_ids, word_cts)

# %%
parsed_corpus = parse_data(doc)
number_of_topics = 4
number_of_types = len(type_to_index)
number_of_documents = len(parsed_corpus[0])
alpha_alpha = np.zeros(number_of_topics) + 1/number_of_topics
alpha_beta = np.zeros(number_of_types) + 1/number_of_types
eta = np.random.gamma(100., 1./100., (number_of_topics,number_of_types))
gamma = numpy.zeros((number_of_documents, number_of_topics)) + alpha_alpha[numpy.newaxis, :] + 1.0 * number_of_types / number_of_topics
word_ids = parsed_corpus[0]
word_cts = parsed_corpus[1]       
number_of_documents = len(word_ids) 
hyper_parameter_optimize_interval=1

# %%
def compute_dirichlet_expectation(dirichlet_parameter):
    if (len(dirichlet_parameter.shape) == 1):
        return (sp.special.psi(dirichlet_parameter) -sp.special.psi(numpy.sum(dirichlet_parameter)))
    return (sp.special.psi(dirichlet_parameter) - sp.special.psi(np.sum(dirichlet_parameter, 1))[:, numpy.newaxis])

# %%
def e_step(parsed_corpus=None,local_parameter_iteration=50,
local_parameter_converge_threshold=1e-6):
             
    document_log_likelihood = 0
    words_log_likelihood = 0

    # initialize a V-by-K matrix phi sufficient statistics
    phi_sufficient_statistics = np.zeros((number_of_topics, number_of_types))

    # initialize a D-by-K matrix gamma values
    gamma_values = np.zeros((number_of_documents, number_of_topics)) + alpha_alpha[np.newaxis, :] + 1.0 * number_of_types / number_of_topics

    E_log_eta = compute_dirichlet_expectation(eta)
    E_log_prob_eta = E_log_eta - sp.misc.logsumexp(E_log_eta, axis=1)[:, np.newaxis]

    # iterate over all documents
    for doc_id in np.random.permutation(number_of_documents):
        # compute the total number of words
        # total_word_count = corpus[doc_id].N()
        total_word_count = np.sum(word_cts[doc_id])

        # initialize gamma for this document
        gamma_values[doc_id, :] = alpha_alpha + 1.0 * total_word_count / number_of_topics

        term_ids = word_ids[doc_id]
        term_counts = word_cts[doc_id]

        # update phi and gamma until gamma converges
        for gamma_iteration in range(local_parameter_iteration):
            log_phi = E_log_eta[:, term_ids].T + np.tile(sp.special.psi(gamma_values[doc_id, :]), (word_ids[doc_id].shape[0], 1))

            log_phi -= sp.misc.logsumexp(log_phi, axis=1)[:, np.newaxis]

            gamma_update = alpha_alpha + np.array(np.sum(np.exp(log_phi + np.log(np.repeat(term_counts, 4, axis=0).T)), axis=0))

            mean_change = np.mean(abs(gamma_update - gamma_values[doc_id, :]))
            gamma_values[doc_id, :] = gamma_update
            if mean_change <= local_parameter_converge_threshold:
                break

        # compute the alpha terms
        document_log_likelihood += sp.special.gammaln(np.sum(alpha_alpha)) - np.sum(sp.special.gammaln(alpha_alpha))
        # compute the gamma terms
        document_log_likelihood += np.sum(sp.special.gammaln(gamma_values[doc_id, :])) - sp.special.gammaln(np.sum(gamma_values[doc_id, :]))
        # compute the phi terms
        document_log_likelihood -= np.sum(np.dot(term_counts, np.exp(log_phi) * log_phi))

# compute the p(w_{dn} | z_{dn}, \eta) terms, which will be cancelled during M-step during training
        words_log_likelihood += np.sum(np.exp(log_phi.T + np.log(term_counts)) * E_log_prob_eta[:, term_ids])      
        phi_sufficient_statistics[:, term_ids] += np.exp(log_phi + np.log(term_counts.transpose())).T
        
    if parsed_corpus == None:
        gamma = gamma_values
        return (document_log_likelihood, phi_sufficient_statistics, gamma)
    else:
        return (words_log_likelihood, gamma_values)

# %%
def m_step(phi_sufficient_statistics):
        # Note: all terms including E_q[p(\eta|\beta)], i.e., terms involving \Psi(\eta), are cancelled due to \eta updates
            
        # compute the beta terms
        topic_log_likelihood = number_of_topics * (sp.special.gammaln(np.sum(alpha_beta)) - np.sum(sp.special.gammaln(alpha_beta)))
        # compute the eta terms
        topic_log_likelihood += np.sum(np.sum(sp.special.gammaln(eta), axis=1) - sp.special.gammaln(np.sum(eta, axis=1)))
        
        eta_temp = phi_sufficient_statistics + alpha_beta
        
        # compute the sufficient statistics for alpha and update
        alpha_sufficient_statistics = sp.special.psi(gamma) - sp.special.psi(np.sum(gamma, axis=1)[:, np.newaxis]);
        alpha_sufficient_statistics = np.sum(alpha_sufficient_statistics, axis=0);  # [np.newaxis, :];
        
        return (topic_log_likelihood, alpha_sufficient_statistics, eta_temp)

# %%
document_log_likelihood, phi_sufficient_statistics, gamma = e_step()
topic_log_likelihood, alpha_sufficient_statistics, eta = m_step(phi_sufficient_statistics)
joint_log_likelihood = document_log_likelihood + topic_log_likelihood

# %%
def optimize_hyperparameters(alpha_sufficient_statistics, hyper_parameter_iteration=100, hyper_parameter_decay_factor=0.9, hyper_parameter_maximum_decay=10,alpha=alpha_alpha, hyper_parameter_converge_threshold=1e-6):

        alpha_update = alpha;        
        decay = 0;
        for alpha_iteration in range(hyper_parameter_iteration):
            alpha_sum = np.sum(alpha)
            alpha_gradient = number_of_documents * (sp.special.psi(alpha_sum) - sp.special.psi(alpha)) + alpha_sufficient_statistics
            alpha_hessian = -number_of_documents * sp.special.polygamma(1,alpha)

            if np.any(np.isinf(alpha_gradient)) or np.any(np.isnan(alpha_gradient)):
                print ("illegal alpha gradient vector", alpha_gradient)

            sum_g_h = np.sum(alpha_gradient / alpha_hessian)
            sum_1_h = 1.0 / alpha_hessian

            z = number_of_documents * sp.special.polygamma(1, alpha_sum)
            c = sum_g_h / (1.0 / z + sum_1_h)

            # update the alpha vector
            while True:
                singular_hessian = False

                step_size = np.power(hyper_parameter_decay_factor, decay) * (alpha_gradient - c) / alpha_hessian
                
                if np.any(alpha <= step_size):
                    singular_hessian = True
                else:
                    alpha_update = alpha - step_size;
                
                if singular_hessian:
                    decay += 1;
                    if decay > hyper_parameter_maximum_decay:
                        break;
                else:
                    break;
                
            # compute the alpha sum
            # check the alpha converge criteria
            mean_change = np.mean(abs(alpha_update - alpha));
            alpha = alpha_update;
            if mean_change <= hyper_parameter_converge_threshold:
                break;

        return (alpha)

# %%
alpha_alpha = optimize_hyperparameters(alpha_sufficient_statistics)

# %%
words_log_likelihood, corpus_gamma_values = e_step(parsed_corpus = parsed_corpus)

# %%
E_log_eta = compute_dirichlet_expectation(eta);
for topic_index in range(number_of_topics):
    print("==========\t%d\t==========\n" % (topic_index))

    beta_probability = np.exp(E_log_eta[topic_index, :] - sp.misc.logsumexp(E_log_eta[topic_index, :]));

    i = 0;
    for type_index in reversed(np.argsort(beta_probability)):
        i += 1;
        print("%s\t%g\n" % (index_to_type[type_index], beta_probability[type_index]));
# Out:
# ==========	0	==========
#
# year	0.006289
#
# peopl	0.00508852
#
# percent	0.00492242
#
# report	0.00427809
#
# two	0.00417133
#
# presid	0.00398333
#
# new	0.00372377
#
# nation	0.00340916
#
# time	0.00340066
#
# state	0.00334827
#
# offic	0.00328299
#
# last	0.00315835
#
# bush	0.00310807
#
# million	0.00297081
#
# govern	0.0028922
#
# first	0.00282069
#
# expect	0.00267743
#
# soviet	0.00267399
#
# today	0.00266388
#
# plan	0.00260563
#
# go	0.00250206
#
# compani	0.00250122
#
# billion	0.00248521
#
# offici	0.00248396
#
# work	0.00246206
#
# call	0.00244539
#
# cent	0.00244284
#
# market	0.00243534
#
# forc	0.00239487
#
# day	0.00238233
#
# price	0.00236003
#
# say	0.00235416
#
# citi	0.00227516
#
# countri	0.00223473
#
# share	0.00214421
#
# make	0.00213992
#
# trade	0.00212436
#
# bank	0.002022
#
# american	0.00202108
#
# congress	0.00201211
#
# hou	0.00198549
#
# court	0.00198223
#
# unit	0.00197996
#
# told	0.00188563
#
# feder	0.00187642
#
# public	0.00184894
#
# rate	0.00183583
#
# wednesday	0.0018089
#
# south	0.00178073
#
# get	0.00177984
#
# depart	0.00177451
#
# tuesday	0.00175973
#
# back	0.00174442
#
# home	0.00174129
#
# member	0.00173017
#
# polic	0.00170369
#
# group	0.00170288
#
# servic	0.0016987
#
# kill	0.00168308
#
# stock	0.00167149
#
# support	0.00166379
#
# month	0.00165744
#
# gener	0.0016569
#
# monday	0.00165276
#
# made	0.0016176
#
# live	0.00160736
#
# increa	0.00156747
#
# friday	0.00155401
#
# three	0.00155093
#
# week	0.00154983
#
# case	0.00154485
#
# charg	0.00152049
#
# parti	0.00151592
#
# world	0.00149927
#
# famili	0.00149129
#
# news	0.0014868
#
# thursday	0.00148279
#
# air	0.00148002
#
# open	0.00147275
#
# investig	0.00147223
#
# tax	0.00142522
#
# like	0.00141904
#
# right	0.00140088
#
# york	0.00139028
#
# come	0.00138225
#
# dont	0.00138064
#
# drug	0.00137528
#
# think	0.00136692
#
# help	0.001366
#
# high	0.00136477
#
# busi	0.00136247
#
# militari	0.00136151
#
# oper	0.00135843
#
# close	0.00134909
#
# found	0.00134478
#
# attorney	0.00134405
#
# show	0.001333
#
# sale	0.00132908
#
# vote	0.0013214
#
# north	0.00131801
#
# program	0.00131748
#
# order	0.00131246
#
# offer	0.00130803
#
# issu	0.0013016
#
# west	0.0013012
#
# japan	0.00129908
#
# leader	0.00129395
#
# union	0.00129299
#
# move	0.00129057
#
# area	0.00128718
#
# ask	0.00128399
#
# industri	0.00126877
#
# administr	0.00125588
#
# fire	0.0012548
#
# futur	0.00125453
#
# number	0.00124054
#
# end	0.00122715
#
# take	0.00122697
#
# test	0.00121842
#
# base	0.00121058
#
# believ	0.00120652
#
# four	0.00120607
#
# problem	0.00119742
#
# night	0.0011818
#
# die	0.00118149
#
# tri	0.00118026
#
# children	0.00117576
#
# death	0.00117097
#
# student	0.00116256
#
# corp	0.00116253
#
# relea	0.00115812
#
# democrat	0.00115802
#
# spokesman	0.00115662
#
# higher	0.00115434
#
# foreign	0.00114579
#
# secur	0.00113671
#
# system	0.00113505
#
# left	0.00113017
#
# control	0.00112643
#
# oil	0.00112508
#
# late	0.001123
#
# meet	0.00112069
#
# arrest	0.00111202
#
# develop	0.00110784
#
# recent	0.00110772
#
# receiv	0.00110741
#
# chang	0.00110243
#
# product	0.00109983
#
# defen	0.00109713
#
# record	0.00109188
#
# financ	0.00107687
#
# ad	0.00107679
#
# place	0.00107231
#
# cost	0.00107198
#
# name	0.00107174
#
# board	0.00107057
#
# univ	0.00107015
#
# allow	0.00106679
#
# director	0.00106335
#
# look	0.00105675
#
# march	0.00105662
#
# hour	0.00105593
#
# polit	0.00104807
#
# remain	0.00104787
#
# dollar	0.00104768
#
# mr	0.00104466
#
# attack	0.00104062
#
# inc	0.00103906
#
# talk	0.00103871
#
# cau	0.00103306
#
# hear	0.00103094
#
# school	0.00102764
#
# law	0.00102193
#
# build	0.00101459
#
# center	0.00101284
#
# yearold	0.00101267
#
# deci	0.00101093
#
# cut	0.00101073
#
# agreement	0.00100478
#
# return	0.000995116
#
# earlier	0.000993836
#
# war	0.000993467
#
# interest	0.000991933
#
# senat	0.000988027
#
# associ	0.000987111
#
# job	0.000986865
#
# point	0.000986436
#
# prison	0.000985273
#
# mile	0.000983364
#
# aid	0.000981901
#
# campaign	0.000978816
#
# good	0.000977209
#
# came	0.000974816
#
# committ	0.000973667
#
# continu	0.000972541
#
# organ	0.000969065
#
# minist	0.00096605
#
# involv	0.000964383
#
# life	0.000962062
#
# give	0.000957728
#
# commun	0.000957213
#
# studi	0.000953722
#
# know	0.000953307
#
# protest	0.00095142
#
# author	0.000950096
#
# employ	0.000948507
#
# money	0.000948443
#
# reagan	0.000944493
#
# ago	0.000939152
#
# fund	0.000937636
#
# bill	0.000937242
#
# white	0.000936839
#
# statement	0.000931452
#
# declin	0.000921288
#
# hold	0.000914903
#
# east	0.000911585
#
# propo	0.000907434
#
# lower	0.000902082
#
# total	0.000899277
#
# arm	0.000899203
#
# worker	0.000898774
#
# demand	0.00089255
#
# water	0.000890864
#
# israel	0.00089073
#
# comput	0.000887508
#
# judg	0.000879505
#
# sunday	0.000875729
#
# sentenc	0.000875253
#
# consid	0.000874027
#
# need	0.000872007
#
# street	0.000871734
#
# long	0.000871082
#
# co	0.000868481
#
# put	0.000866897
#
# play	0.000861271
#
# america	0.00085923
#
# econom	0.000856668
#
# announc	0.000854865
#
# appear	0.00085176
#
# rule	0.00084292
#
# question	0.000841751
#
# agr	0.000840256
#
# thing	0.000839297
#
# see	0.000838838
#
# earli	0.000838692
#
# claim	0.000838569
#
# want	0.000836141
#
# exchang	0.00083568
#
# chairman	0.000833974
#
# th	0.000833029
#
# southern	0.000831481
#
# chief	0.000830882
#
# peac	0.000829835
#
# analyst	0.000826729
#
# counti	0.000822077
#
# intern	0.000818557
#
# elect	0.000816313
#
# william	0.00080877
#
# index	0.000807716
#
# head	0.000804985
#
# victim	0.000804755
#
# april	0.000800263
#
# leav	0.000798795
#
# manag	0.000793601
#
# provid	0.000792789
#
# john	0.000791389
#
# troop	0.000790528
#
# result	0.000789905
#
# effect	0.000789547
#
# iraq	0.000789209
#
# press	0.000788901
#
# polici	0.000787724
#
# keep	0.000784982
#
# economi	0.000779016
#
# man	0.000775009
#
# six	0.000770977
#
# vice	0.000769095
#
# line	0.000768107
#
# form	0.000765361
#
# research	0.000762177
#
# requir	0.00076052
#
# reach	0.00075939
#
# deal	0.000757969
#
# execut	0.000757335
#
# second	0.000755934
#
# condit	0.000753806
#
# men	0.000752712
#
# activ	0.000750708
#
# agenc	0.00075033
#
# fell	0.000748902
#
# top	0.000745293
#
# face	0.000743043
#
# five	0.000742397
#
# iraqi	0.000742375
#
# capit	0.000741786
#
# effort	0.000741056
#
# possibl	0.000739604
#
# file	0.000737782
#
# sen	0.000737732
#
# robert	0.000736057
#
# run	0.000735642
#
# trial	0.000733028
#
# accid	0.000731664
#
# district	0.000729304
#
# person	0.000727745
#
# justic	0.000725447
#
# black	0.000721245
#
# start	0.000715982
#
# fail	0.000715635
#
# turn	0.000711802
#
# held	0.000709545
#
# ship	0.00070354
#
# damag	0.000702574
#
# import	0.000699044
#
# drop	0.000698857
#
# littl	0.000696199
#
# bodi	0.000695526
#
# car	0.000695039
#
# averag	0.000688844
#
# central	0.000688756
#
# visit	0.000686807
#
# major	0.000685767
#
# valu	0.000684081
#
# great	0.000679436
#
# lead	0.000677062
#
# note	0.000676929
#
# measur	0.000676387
#
# estim	0.000676155
#
# human	0.000672279
#
# comment	0.000669632
#
# away	0.000668595
#
# approv	0.000668089
#
# town	0.000667524
#
# indic	0.000666922
#
# schedul	0.000666665
#
# didnt	0.000663291
#
# secretari	0.000662647
#
# project	0.0006608
#
# power	0.000658876
#
# hospit	0.000655605
#
# gain	0.000654943
#
# saturday	0.000650819
#
# inform	0.000650103
#
# arriv	0.000649968
#
# rai	0.000649655
#
# rose	0.000645265
#
# critic	0.000643469
#
# im	0.00064111
#
# convict	0.000637289
#
# privat	0.000636776
#
# act	0.000635335
#
# posit	0.000634641
#
# wife	0.000632789
#
# got	0.000629986
#
# contract	0.000628544
#
# account	0.00062807
#
# morn	0.000626796
#
# repr	0.000626121
#
# german	0.00061784
#
# lost	0.0006175
#
# negoti	0.000616925
#
# pay	0.000616239
#
# hand	0.000614935
#
# women	0.000613646
#
# labor	0.000612838
#
# shot	0.000612554
#
# carri	0.00061032
#
# alleg	0.000605952
#
# british	0.000604069
#
# son	0.000603717
#
# california	0.000603262
#
# armi	0.000602059
#
# washington	0.000600441
#
# plane	0.000597291
#
# governor	0.000595522
#
# hope	0.000593183
#
# level	0.000592097
#
# region	0.00059195
#
# known	0.000590599
#
# produc	0.000589839
#
# protect	0.00058949
#
# june	0.000588411
#
# outsid	0.000587839
#
# ill	0.000586893
#
# bid	0.000582798
#
# big	0.000582398
#
# remov	0.0005821
#
# follow	0.000582073
#
# dukaki	0.000582073
#
# perform	0.000580369
#
# respon	0.00057805
#
# jame	0.000576331
#
# coast	0.00057402
#
# food	0.000572144
#
# televi	0.000570216
#
# san	0.000567591
#
# attempt	0.000565433
#
# eight	0.000564185
#
# gorbachev	0.000563553
#
# half	0.000562854
#
# current	0.000562574
#
# prime	0.000561064
#
# spend	0.000560208
#
# eastern	0.000559644
#
# pound	0.000557606
#
# immedi	0.000557462
#
# publish	0.000557438
#
# stop	0.000557276
#
# land	0.000557095
#
# differ	0.00055654
#
# store	0.000555521
#
# murder	0.000553769
#
# best	0.000552489
#
# appeal	0.000551896
#
# health	0.000551276
#
# commiss	0.000550677
#
# young	0.000550417
#
# resid	0.000550379
#
# sell	0.000548426
#
# largest	0.000548248
#
# concern	0.000545297
#
# lo	0.000544892
#
# accu	0.000544051
#
# sign	0.000543581
#
# suffer	0.000542662
#
# lawyer	0.000541368
#
# previou	0.000540869
#
# friend	0.000540059
#
# design	0.000539753
#
# london	0.000538597
#
# guard	0.000536534
#
# seek	0.000534952
#
# suggest	0.000534693
#
# action	0.000533232
#
# addit	0.000533051
#
# republican	0.000532038
#
# begin	0.000531054
#
# taken	0.000530796
#
# went	0.000530303
#
# complet	0.000529086
#
# train	0.00052832
#
# ms	0.000526761
#
# budget	0.000525389
#
# discuss	0.000524149
#
# sourc	0.000523327
#
# term	0.000522644
#
# side	0.000522551
#
# rise	0.000521918
#
# social	0.000521572
#
# seven	0.00052078
#
# wall	0.000520355
#
# invest	0.000519838
#
# violat	0.000519516
#
# travel	0.00051904
#
# incom	0.000518117
#
# crime	0.000516293
#
# past	0.00051571
#
# stand	0.000514307
#
# fall	0.000513837
#
# emerg	0.000511545
#
# creat	0.000511507
#
# investor	0.000511491
#
# western	0.000508773
#
# small	0.000507028
#
# medic	0.000506858
#
# compar	0.000506341
#
# germani	0.000505958
#
# reduc	0.00050488
#
# won	0.000504439
#
# assist	0.000504182
#
# wound	0.000503622
#
# fight	0.000502825
#
# angel	0.000502781
#
# institut	0.000502628
#
# request	0.000502479
#
# plant	0.000500568
#
# presidenti	0.00049907
#
# larg	0.000496315
#
# korea	0.000496227
#
# juli	0.000496227
#
# real	0.000495674
#
# abl	0.000495315
#
# opposit	0.000494273
#
# earn	0.000494082
#
# strong	0.000493639
#
# mark	0.000493604
#
# better	0.000492622
#
# warn	0.000491885
#
# newspap	0.000491338
#
# african	0.00049113
#
# cash	0.000490355
#
# hundr	0.000490228
#
# led	0.000488836
#
# done	0.000488403
#
# februari	0.000488361
#
# farm	0.000487303
#
# aug	0.000485939
#
# post	0.000485241
#
# determin	0.000483199
#
# happen	0.000482667
#
# confer	0.000482126
#
# estat	0.000481162
#
# figur	0.000481148
#
# firm	0.000480286
#
# light	0.000479057
#
# septemb	0.000477922
#
# brought	0.000474401
#
# soldier	0.000474366
#
# africa	0.000473822
#
# list	0.000471471
#
# farmer	0.000471388
#
# present	0.000471157
#
# michael	0.000469153
#
# mexico	0.000468433
#
# reason	0.000467341
#
# count	0.000467189
#
# park	0.000466765
#
# franc	0.000466023
#
# independ	0.000465935
#
# navi	0.000465741
#
# mother	0.000465512
#
# river	0.00046548
#
# hit	0.000465432
#
# northern	0.000465328
#
# relat	0.000464171
#
# societi	0.000461899
#
# parent	0.000460797
#
# januari	0.000460636
#
# bring	0.00046039
#
# contact	0.000460078
#
# decid	0.000459589
#
# feel	0.000458968
#
# consum	0.000458693
#
# bond	0.000457417
#
# weapon	0.000456332
#
# loan	0.000455709
#
# sold	0.000453626
#
# profit	0.000453437
#
# gulf	0.000453377
#
# rel	0.000452943
#
# game	0.000452771
#
# lot	0.000452437
#
# dealer	0.000449793
#
# energi	0.000449756
#
# council	0.000448157
#
# commerci	0.000448027
#
# role	0.000447582
#
# direct	0.000447532
#
# review	0.000447164
#
# seriou	0.000447106
#
# loss	0.000446029
#
# old	0.000446027
#
# view	0.000444683
#
# care	0.000444253
#
# seen	0.000443815
#
# kuwait	0.000443733
#
# defend	0.000442758
#
# texa	0.00044177
#
# suprem	0.00044024
#
# palestinian	0.000439406
#
# august	0.000439363
#
# interview	0.000438974
#
# accept	0.000438959
#
# ohio	0.000438256
#
# main	0.000438162
#
# radio	0.000437075
#
# buy	0.000436242
#
# legal	0.000435665
#
# europ	0.00043439
#
# demonstr	0.000434155
#
# panama	0.000433482
#
# launch	0.000433114
#
# thousand	0.000432735
#
# win	0.00043183
#
# refu	0.00043181
#
# quarter	0.000431532
#
# gold	0.0004315
#
# stay	0.000429301
#
# legisl	0.000428925
#
# feet	0.000428231
#
# diplomat	0.000427576
#
# session	0.000427481
#
# limit	0.000427023
#
# king	0.0004264
#
# trust	0.000426379
#
# final	0.000425769
#
# serv	0.000425691
#
# woman	0.000425661
#
# special	0.000425653
#
# film	0.000425611
#
# smith	0.000424938
#
# safeti	0.000424677
#
# declar	0.000424651
#
# wit	0.000422767
#
# aircraft	0.000422462
#
# agricultur	0.00042114
#
# far	0.000420972
#
# gave	0.000420511
#
# collect	0.000420381
#
# senior	0.000419355
#
# chicago	0.000419329
#
# corpor	0.000418059
#
# local	0.000417844
#
# cover	0.000416622
#
# front	0.000414484
#
# airlin	0.00041403
#
# watch	0.000412657
#
# paid	0.000411971
#
# middl	0.000411234
#
# mean	0.000409277
#
# nomin	0.000408833
#
# amount	0.000408326
#
# conserv	0.000407293
#
# star	0.000406907
#
# inflat	0.000406851
#
# ralli	0.000406774
#
# date	0.000406143
#
# testimoni	0.000404127
#
# advi	0.000403666
#
# georg	0.000402712
#
# letter	0.000402524
#
# electr	0.000401556
#
# poor	0.00040146
#
# church	0.000400561
#
# republ	0.000400316
#
# saudi	0.000400171
#
# degr	0.000400029
#
# advanc	0.000399892
#
# reform	0.000399891
#
# improv	0.000398884
#
# thought	0.000398136
#
# environ	0.000398038
#
# facil	0.000397144
#
# deni	0.000396901
#
# deputi	0.000395925
#
# ground	0.000395247
#
# met	0.000394618
#
# isra	0.000394306
#
# david	0.000393425
#
# reject	0.000392527
#
# britain	0.000391841
#
# sent	0.000390558
#
# educ	0.000390075
#
# book	0.000389414
#
# disea	0.0003893
#
# telephon	0.000388888
#
# free	0.000388313
#
# annual	0.000387972
#
# custom	0.000387308
#
# pm	0.000387112
#
# space	0.000387082
#
# let	0.000386902
#
# establish	0.000386653
#
# period	0.000386201
#
# citizen	0.000386184
#
# avail	0.000385008
#
# drive	0.000383901
#
# suppli	0.000383418
#
# speech	0.000381438
#
# summer	0.000381323
#
# command	0.000380979
#
# export	0.000379685
#
# weather	0.000378877
#
# spent	0.000378532
#
# jone	0.000378191
#
# juri	0.000377895
#
# forecast	0.000377797
#
# heart	0.000377441
#
# airport	0.000377135
#
# key	0.000376925
#
# secret	0.000376639
#
# rain	0.000376433
#
# doesnt	0.000376056
#
# spokeswoman	0.000375948
#
# heat	0.000375301
#
# join	0.000375274
#
# urg	0.00037407
#
# matter	0.00037389
#
# reserv	0.000372969
#
# arab	0.00037263
#
# soybean	0.000372155
#
# communist	0.000371413
#
# convent	0.000370244
#
# conduct	0.000370101
#
# destroy	0.000367738
#
# de	0.000366854
#
# b	0.000366765
#
# manufactur	0.00036672
#
# resign	0.000366476
#
# block	0.00036562
#
# prosecutor	0.000365611
#
# injur	0.000364144
#
# movement	0.000363858
#
# individu	0.000363548
#
# motor	0.000362201
#
# origin	0.000362015
#
# grow	0.000360882
#
# engin	0.000360822
#
# art	0.000360102
#
# cant	0.000359845
#
# calif	0.000359621
#
# quot	0.000358819
#
# appar	0.000358502
#
# contain	0.000358442
#
# speak	0.000358248
#
# fair	0.000358141
#
# pentagon	0.000357904
#
# pictur	0.000357821
#
# dozen	0.000356549
#
# realli	0.00035651
#
# save	0.000356412
#
# practic	0.00035567
#
# soon	0.000355519
#
# threat	0.000354879
#
# road	0.000354379
#
# walk	0.000354202
#
# child	0.000353599
#
# materi	0.000353516
#
# island	0.00035341
#
# retir	0.000353381
#
# battl	0.000352667
#
# cour	0.000351875
#
# full	0.00035102
#
# jan	0.000350951
#
# rural	0.000350823
#
# asset	0.000350033
#
# saw	0.000349456
#
# room	0.000349015
#
# ban	0.000349008
#
# replac	0.000348634
#
# appli	0.000348418
#
# club	0.000347846
#
# read	0.000346649
#
# husband	0.000346421
#
# learn	0.000345948
#
# common	0.000345715
#
# jr	0.00034557
#
# situat	0.000344655
#
# illeg	0.000344409
#
# hostag	0.00034407
#
# site	0.000344016
#
# affect	0.00034345
#
# break	0.000343285
#
# door	0.000342148
#
# hotel	0.000342147
#
# yen	0.000341986
#
# idea	0.000341841
#
# refer	0.000341653
#
# florida	0.000341335
#
# describ	0.000341309
#
# mission	0.000341297
#
# injuri	0.00034109
#
# testifi	0.000340263
#
# insur	0.000339765
#
# step	0.000339433
#
# send	0.000338814
#
# economist	0.000338703
#
# race	0.000338044
#
# fact	0.000338014
#
# clear	0.000337288
#
# suspect	0.000336808
#
# crimin	0.000335696
#
# daili	0.000334334
#
# rebel	0.000333341
#
# gov	0.000332902
#
# grant	0.000332196
#
# tell	0.000332195
#
# third	0.000331253
#
# prepar	0.000330582
#
# class	0.000330555
#
# st	0.000330004
#
# word	0.000329713
#
# age	0.000329416
#
# strike	0.000329181
#
# love	0.000329108
#
# process	0.000329106
#
# trader	0.000327845
#
# debt	0.000327719
#
# fear	0.00032741
#
# properti	0.000326659
#
# incid	0.000326611
#
# attend	0.0003262
#
# expen	0.000325982
#
# network	0.000325888
#
# prevent	0.000325172
#
# novemb	0.000323658
#
# pressur	0.000323575
#
# father	0.000322757
#
# heavi	0.000322718
#
# enter	0.000322005
#
# initi	0.00032157
#
# evid	0.00032153
#
# threaten	0.000321224
#
# paul	0.000321071
#
# magazin	0.00032083
#
# music	0.000320077
#
# rock	0.000319479
#
# guilti	0.000319092
#
# deleg	0.000318141
#
# broadcast	0.000317471
#
# stori	0.000317412
#
# grand	0.000317303
#
# crowd	0.000317253
#
# rang	0.000317067
#
# particip	0.000316621
#
# flight	0.000316451
#
# earth	0.000316232
#
# iran	0.000316201
#
# apart	0.000315894
#
# document	0.000315532
#
# colleg	0.00031543
#
# blame	0.000314299
#
# coupl	0.000314295
#
# ticket	0.000314075
#
# fiscal	0.000313984
#
# joseph	0.000313383
#
# violenc	0.000313379
#
# primari	0.000312925
#
# stage	0.000312645
#
# richard	0.000310775
#
# patient	0.000310662
#
# station	0.000310624
#
# biggest	0.000310193
#
# bushel	0.00031002
#
# treat	0.000309055
#
# worth	0.000308979
#
# favor	0.000308412
#
# occur	0.000308404
#
# detail	0.000308014
#
# feb	0.00030731
#
# spoke	0.000307221
#
# minut	0.000306512
#
# volum	0.000306494
#
# guerrilla	0.000306396
#
# enforc	0.000306359
#
# address	0.000306132
#
# award	0.000305169
#
# nine	0.000305076
#
# search	0.000304331
#
# specul	0.000303623
#
# crisi	0.000303488
#
# homeless	0.000303404
#
# paper	0.000302225
#
# owner	0.000302119
#
# constitut	0.000301308
#
# divi	0.000300666
#
# gun	0.00030065
#
# ii	0.000298002
#
# growth	0.000297874
#
# recommend	0.000297699
#
# team	0.000296939
#
# oppo	0.000296934
#
# wait	0.00029676
#
# mecham	0.000296743
#
# season	0.000296492
#
# rep	0.000295709
#
# indict	0.000295634
#
# settlement	0.000295538
#
# wide	0.000295163
#
# delay	0.000294599
#
# survey	0.000294156
#
# cuban	0.000294126
#
# regul	0.000294104
#
# pari	0.000293468
#
# baker	0.000293283
#
# push	0.000293272
#
# histori	0.000292919
#
# revenu	0.000292534
#
# insid	0.00029214
#
# success	0.000291565
#
# korean	0.000291191
#
# foot	0.000290945
#
# identifi	0.000290266
#
# troubl	0.000290082
#
# movi	0.000289818
#
# unchang	0.000289693
#
# singl	0.000289259
#
# contra	0.000289224
#
# contend	0.000289182
#
# recov	0.000289048
#
# tokyo	0.000288112
#
# credit	0.000287784
#
# crew	0.000286935
#
# standard	0.00028679
#
# hard	0.000286665
#
# trip	0.000286386
#
# treatment	0.000286051
#
# octob	0.000285448
#
# affair	0.000285406
#
# examin	0.000285377
#
# actual	0.000285298
#
# burn	0.000285269
#
# rest	0.00028454
#
# despit	0.00028382
#
# summit	0.000283457
#
# neighbor	0.000282145
#
# wind	0.000282008
#
# mayor	0.000281817
#
# benefit	0.000281807
#
# missil	0.000281803
#
# dead	0.000281601
#
# anonym	0.000281504
#
# shuttl	0.000281321
#
# wrote	0.000280535
#
# moscow	0.000280452
#
# crash	0.000280183
#
# contribut	0.00028016
#
# equip	0.000279931
#
# ga	0.000279645
#
# lake	0.000279055
#
# popular	0.000278766
#
# editor	0.000276096
#
# lt	0.00027564
#
# permit	0.000275357
#
# inva	0.000274973
#
# territori	0.000274203
#
# decad	0.000273998
#
# shop	0.000273978
#
# field	0.000273605
#
# democraci	0.000273564
#
# decemb	0.00027337
#
# scientist	0.000273261
#
# dec	0.00027274
#
# saddam	0.000271437
#
# challeng	0.000271039
#
# villag	0.000270749
#
# shoot	0.00027059
#
# worri	0.000270331
#
# oct	0.000270135
#
# packag	0.000270075
#
# signif	0.000270037
#
# impo	0.00026992
#
# civil	0.000269841
#
# vehicl	0.000269573
#
# deficit	0.000269287
#
# potenti	0.000268828
#
# due	0.000268809
#
# storm	0.000268287
#
# confirm	0.000268024
#
# finish	0.000267847
#
# specif	0.000267794
#
# pull	0.000267463
#
# liber	0.000267297
#
# joint	0.000266291
#
# settl	0.000266227
#
# activist	0.000266094
#
# bar	0.000265194
#
# boost	0.000265014
#
# cocain	0.000264953
#
# wasnt	0.000264663
#
# knew	0.00026279
#
# resolut	0.000262676
#
# separ	0.000262522
#
# exist	0.000262344
#
# daughter	0.000262274
#
# purcha	0.000261368
#
# entir	0.000261289
#
# immigr	0.000261276
#
# domest	0.000260931
#
# failur	0.000260928
#
# doctor	0.000260865
#
# jump	0.000260852
#
# acquir	0.000260128
#
# nasa	0.000259685
#
# media	0.000259077
#
# teacher	0.000258713
#
# express	0.000258527
#
# avoid	0.000258489
#
# plead	0.000258454
#
# danger	0.000258254
#
# panel	0.000257768
#
# dow	0.000257485
#
# refug	0.000257426
#
# influenc	0.000257013
#
# dr	0.000256898
#
# freedom	0.000256797
#
# chrysler	0.000256601
#
# pass	0.000256559
#
# thoma	0.000255513
#
# hill	0.000255494
#
# ford	0.000254954
#
# risk	0.000254666
#
# weve	0.000253762
#
# corn	0.00025365
#
# signal	0.000253549
#
# c	0.000253502
#
# approach	0.000253371
#
# assembl	0.000252921
#
# promi	0.000252665
#
# china	0.000252572
#
# afternoon	0.000252015
#
# commit	0.000251698
#
# downtown	0.000251497
#
# competit	0.000251108
#
# staff	0.000250207
#
# maintain	0.000249389
#
# noriega	0.000248963
#
# spread	0.000248692
#
# fitzwat	0.000248681
#
# tree	0.000248503
#
# passeng	0.000248247
#
# treati	0.000248229
#
# minor	0.000248074
#
# jail	0.00024708
#
# kind	0.0002468
#
# distribut	0.000246675
#
# valley	0.000246673
#
# messag	0.000246348
#
# bomb	0.000246254
#
# fine	0.000245176
#
# flood	0.000245109
#
# parliament	0.000244435
#
# surviv	0.000244393
#
# fish	0.000244137
#
# helicopt	0.000243828
#
# hurt	0.000243406
#
# transport	0.000243303
#
# acknowledg	0.000243109
#
# broke	0.000243037
#
# expert	0.000243
#
# francisco	0.000242708
#
# donald	0.0002423
#
# boston	0.000242065
#
# low	0.000241848
#
# fli	0.000241183
#
# inch	0.000241156
#
# fourth	0.00024038
#
# consult	0.00024028
#
# payment	0.000240258
#
# candid	0.000240099
#
# crop	0.000240071
#
# event	0.000240028
#
# european	0.000239177
#
# ton	0.000239116
#
# admit	0.000238988
#
# grain	0.000238893
#
# respond	0.000238887
#
# disput	0.000238675
#
# un	0.000238289
#
# fatal	0.000237907
#
# agent	0.000237458
#
# nuclear	0.000237196
#
# jet	0.000236965
#
# bad	0.000236909
#
# acr	0.000236811
#
# cultur	0.000236653
#
# sept	0.00023594
#
# readi	0.000235822
#
# opportun	0.000235772
#
# shortli	0.000235647
#
# la	0.000235437
#
# natur	0.00023504
#
# l	0.000235016
#
# tape	0.000234798
#
# cathol	0.000234668
#
# short	0.000234378
#
# heard	0.000233725
#
# sever	0.000233437
#
# theyr	0.000232935
#
# mind	0.000232909
#
# nov	0.000232334
#
# intend	0.000231875
#
# withdraw	0.000231774
#
# piec	0.000231606
#
# pilot	0.000231463
#
# commerc	0.000231268
#
# temperatur	0.000231164
#
# object	0.000231006
#
# christian	0.000230922
#
# construct	0.000230402
#
# dismiss	0.000230379
#
# chanc	0.000230339
#
# border	0.000230194
#
# memori	0.000229946
#
# fuel	0.000229494
#
# virginia	0.000229336
#
# miss	0.000229236
#
# iii	0.000228711
#
# subject	0.000228316
#
# restrict	0.000228067
#
# strength	0.000227744
#
# penalti	0.000227637
#
# kept	0.000227608
#
# written	0.000227604
#
# occupi	0.000227482
#
# detroit	0.000227467
#
# lawmak	0.000226647
#
# check	0.000226438
#
# amend	0.000226203
#
# wave	0.000226063
#
# abc	0.000225582
#
# elimin	0.000225464
#
# ounc	0.000225406
#
# voter	0.000225051
#
# expand	0.000225029
#
# mall	0.000224991
#
# moslem	0.000224036
#
# answer	0.000223941
#
# seri	0.000223603
#
# correct	0.000223573
#
# write	0.000223381
#
# safe	0.000223235
#
# tank	0.000223169
#
# transfer	0.000222821
#
# sure	0.00022256
#
# link	0.000222518
#
# round	0.000222409
#
# formal	0.000222304
#
# currenc	0.000221641
#
# takeov	0.000221307
#
# unabl	0.000221146
#
# tv	0.000221125
#
# focu	0.000220771
#
# victori	0.000219616
#
# struggl	0.000219223
#
# arabia	0.00021902
#
# restor	0.00021897
#
# indian	0.000217957
#
# m	0.000217785
#
# dc	0.000217689
#
# civilian	0.000217587
#
# lift	0.000217213
#
# boy	0.000216861
#
# suit	0.000216588
#
# lie	0.000215665
#
# brother	0.000215126
#
# atlanta	0.000215091
#
# jewish	0.000215065
#
# quickli	0.000214981
#
# latest	0.000214656
#
# remark	0.000214213
#
# french	0.000213742
#
# blood	0.000213344
#
# handl	0.00021259
#
# actor	0.00021245
#
# johnson	0.000212383
#
# vessel	0.000212341
#
# detain	0.000212234
#
# mph	0.00021204
#
# progress	0.000211776
#
# impact	0.00021175
#
# headquart	0.000211228
#
# popul	0.000210858
#
# complain	0.000210652
#
# hire	0.000210605
#
# find	0.000210465
#
# rank	0.000209516
#
# abu	0.000209067
#
# tie	0.000208947
#
# normal	0.000208843
#
# technolog	0.00020871
#
# pretti	0.000208045
#
# camp	0.000207853
#
# recal	0.000207696
#
# voic	0.000207551
#
# pacif	0.000207496
#
# bob	0.000207279
#
# kennedi	0.000207151
#
# difficult	0.000207147
#
# assault	0.000206528
#
# cross	0.000206435
#
# scene	0.000206374
#
# wouldnt	0.000206151
#
# yield	0.000205487
#
# smoke	0.000205365
#
# boat	0.000205188
#
# marin	0.000204647
#
# girl	0.000204303
#
# chemic	0.000204296
#
# floor	0.000204277
#
# reduct	0.000204189
#
# mass	0.000204172
#
# ive	0.000203586
#
# henri	0.000202921
#
# goe	0.000202783
#
# everybodi	0.000202479
#
# monitor	0.000202151
#
# smaller	0.000202143
#
# climb	0.000202096
#
# articl	0.000201884
#
# subcommitt	0.000201608
#
# aboard	0.000201354
#
# innoc	0.000201258
#
# seat	0.000201238
#
# promot	0.000201179
#
# chine	0.000200971
#
# resolv	0.000200879
#
# weak	0.00020087
#
# basi	0.000200693
#
# experi	0.000200517
#
# eye	0.000200377
#
# pick	0.000199689
#
# connect	0.000198867
#
# resourc	0.000198537
#
# lose	0.000198097
#
# fraud	0.000197357
#
# clean	0.000197183
#
# arrang	0.000197054
#
# even	0.000196982
#
# lawsuit	0.000196936
#
# infect	0.000196605
#
# draw	0.000196461
#
# confid	0.000196442
#
# massachusett	0.00019637
#
# brown	0.000195911
#
# wage	0.000195868
#
# wine	0.000195608
#
# structur	0.000195194
#
# adopt	0.000195187
#
# deep	0.00019513
#
# treasuri	0.000195041
#
# winter	0.000194853
#
# deliveri	0.000194761
#
# riot	0.000194737
#
# way	0.000194647
#
# target	0.000194419
#
# brief	0.000194371
#
# encourag	0.000194153
#
# locat	0.00019409
#
# bought	0.000193833
#
# cooper	0.000193671
#
# auto	0.000193414
#
# cancer	0.000193227
#
# sharpli	0.000193139
#
# metal	0.000192952
#
# composit	0.000192802
#
# coalit	0.000192586
#
# crude	0.000192264
#
# gather	0.000192157
#
# persian	0.000191744
#
# loui	0.000191423
#
# slightli	0.00019111
#
# disclo	0.000191039
#
# poll	0.000190303
#
# longer	0.000190275
#
# beach	0.000190221
#
# sister	0.00019014
#
# leadership	0.000189954
#
# extend	0.000189952
#
# nbc	0.000189893
#
# nationwid	0.00018986
#
# predict	0.00018979
#
# snow	0.000189615
#
# cabinet	0.000189581
#
# firefight	0.000189438
#
# religi	0.000189385
#
# thompson	0.000189362
#
# mail	0.000188382
#
# abort	0.000188089
#
# cattl	0.000188032
#
# forward	0.00018741
#
# necessari	0.00018728
#
# plea	0.000187277
#
# devic	0.00018722
#
# collap	0.000186707
#
# mikhail	0.000186681
#
# select	0.000186676
#
# fled	0.000186525
#
# rescu	0.000186501
#
# condom	0.000186356
#
# subsidiari	0.000186268
#
# honor	0.000186173
#
# blue	0.000185884
#
# set	0.000185375
#
# kid	0.000185295
#
# wast	0.000185231
#
# couldnt	0.00018519
#
# reflect	0.000185027
#
# tradit	0.00018499
#
# ea	0.000184949
#
# recess	0.000184891
#
# built	0.000184753
#
# felt	0.000184451
#
# debat	0.00018433
#
# slow	0.000184178
#
# terrorist	0.000183838
#
# alli	0.00018363
#
# racial	0.000183308
#
# widespread	0.000182871
#
# centuri	0.000182791
#
# celebr	0.00018279
#
# prompt	0.000182653
#
# observ	0.000182376
#
# houston	0.000182212
#
# red	0.000182211
#
# permiss	0.000181832
#
# wheat	0.000181789
#
# wont	0.000181784
#
# wrong	0.000181737
#
# aggress	0.000181045
#
# duti	0.000180676
#
# assur	0.000180605
#
# ministri	0.000180589
#
# data	0.000180586
#
# electron	0.000180123
#
# dump	0.00018003
#
# forest	0.000179513
#
# cb	0.000179498
#
# dress	0.000179376
#
# abandon	0.000179351
#
# portion	0.000179294
#
# heavili	0.000179277
#
# highest	0.000178864
#
# section	0.000178702
#
# southwest	0.000178546
#
# barrel	0.000178484
#
# disast	0.000178413
#
# histor	0.000178183
#
# applic	0.00017814
#
# ec	0.00017804
#
# columbia	0.000177758
#
# professor	0.00017754
#
# greater	0.000177527
#
# access	0.000177505
#
# provinc	0.000176981
#
# mee	0.000176899
#
# sport	0.000176873
#
# laboratori	0.000176768
#
# jim	0.000176568
#
# insist	0.000176251
#
# aim	0.000176186
#
# huge	0.000175674
#
# partner	0.000175377
#
# understand	0.000175338
#
# merger	0.000175254
#
# rival	0.000175245
#
# proceed	0.000174856
#
# neighborhood	0.000174514
#
# doubl	0.000174398
#
# gone	0.000174389
#
# gen	0.000174228
#
# mississippi	0.000173839
#
# surpri	0.00017361
#
# model	0.000173449
#
# danc	0.000173449
#
# copi	0.000173287
#
# nearbi	0.000173001
#
# bishop	0.000172976
#
# fee	0.000172974
#
# peter	0.00017294
#
# quit	0.000172898
#
# offen	0.000172202
#
# atlant	0.00017204
#
# sharehold	0.000171846
#
# statu	0.00017143
#
# larger	0.000171338
#
# warrant	0.000171207
#
# roman	0.000171185
#
# irv	0.000171134
#
# counsel	0.00017056
#
# lack	0.000170364
#
# gasolin	0.000170228
#
# lee	0.000170019
#
# size	0.000169966
#
# yard	0.000169303
#
# machin	0.000169057
#
# band	0.000168915
#
# charl	0.00016879
#
# argument	0.000168489
#
# unemploy	0.000168289
#
# silver	0.00016827
#
# introduc	0.000168206
#
# spring	0.00016819
#
# contractor	0.000167777
#
# commod	0.000167208
#
# sought	0.000167039
#
# restaur	0.000166978
#
# christma	0.000166971
#
# sit	0.000166916
#
# cancel	0.000166672
#
# argu	0.000166649
#
# northwest	0.000166612
#
# theater	0.000166069
#
# gallon	0.000166042
#
# sound	0.000165922
#
# fla	0.000165727
#
# defeat	0.000165401
#
# sandinista	0.00016533
#
# personnel	0.000165131
#
# tour	0.000165126
#
# jew	0.000165054
#
# magellan	0.000164789
#
# draft	0.00016478
#
# northeast	0.000164103
#
# born	0.000163739
#
# item	0.000163593
#
# surgeri	0.00016358
#
# photograph	0.000163343
#
# eventu	0.00016334
#
# transact	0.000163321
#
# bridg	0.000163263
#
# discov	0.000163017
#
# lend	0.000162837
#
# prospect	0.000162761
#
# explain	0.000162501
#
# appoint	0.000162111
#
# fed	0.000162093
#
# resist	0.000162074
#
# retail	0.000161924
#
# bu	0.000161918
#
# edward	0.000161833
#
# illinoi	0.000161809
#
# sea	0.000161594
#
# wood	0.000161233
#
# miner	0.00016094
#
# j	0.000160837
#
# deliv	0.000160833
#
# virtual	0.000160808
#
# truck	0.000160737
#
# hail	0.000160552
#
# port	0.000160451
#
# mountain	0.000160401
#
# pope	0.000160386
#
# ir	0.000159941
#
# mix	0.00015969
#
# dole	0.000159665
#
# sanction	0.000159593
#
# nazi	0.000159517
#
# sponsor	0.000159516
#
# welcom	0.000159311
#
# doubt	0.000159171
#
# weekend	0.000158929
#
# deploy	0.000158666
#
# sheriff	0.000158659
#
# turkey	0.000158614
#
# combin	0.00015838
#
# regard	0.000158307
#
# berlin	0.000158196
#
# e	0.000158102
#
# teenag	0.000157708
#
# burden	0.000157467
#
# ahead	0.00015707
#
# plain	0.000156834
#
# complaint	0.000156723
#
# sector	0.000156625
#
# italian	0.000156563
#
# isnt	0.000156237
#
# h	0.000156074
#
# olymp	0.000156031
#
# ambassador	0.000155744
#
# depend	0.000155712
#
# prove	0.000155618
#
# obviou	0.000155562
#
# guarant	0.000155538
#
# itali	0.000155362
#
# islam	0.000154899
#
# drexel	0.000154853
#
# partnership	0.000154507
#
# evacu	0.000154383
#
# tass	0.000154136
#
# shamir	0.000154075
#
# weekli	0.000153913
#
# f	0.000153834
#
# macmillan	0.000153746
#
# temporari	0.000153698
#
# hussein	0.000153555
#
# fill	0.000153487
#
# pend	0.000153186
#
# pact	0.000152727
#
# task	0.000152559
#
# pork	0.000152493
#
# conclud	0.000152372
#
# repeat	0.000152283
#
# radic	0.000152244
#
# guy	0.000152054
#
# factor	0.000152043
#
# cite	0.000151805
#
# el	0.000151686
#
# england	0.000151656
#
# pledg	0.000151508
#
# strip	0.000151463
#
# explo	0.000151287
#
# punish	0.000151232
#
# invit	0.000150735
#
# song	0.000150722
#
# thank	0.000150644
#
# milken	0.000150614
#
# exil	0.000150059
#
# anim	0.000150058
#
# speed	0.000149966
#
# rumor	0.000149777
#
# hot	0.000149717
#
# combat	0.000149697
#
# page	0.000149298
#
# basic	0.000149262
#
# patrol	0.000149115
#
# museum	0.000149043
#
# martin	0.000148681
#
# singer	0.000148673
#
# terror	0.000148584
#
# santa	0.000148469
#
# att	0.000147985
#
# inmat	0.000147939
#
# bird	0.000147544
#
# spot	0.000147471
#
# embassi	0.000147426
#
# nj	0.000147408
#
# gop	0.000147395
#
# ran	0.000147094
#
# philippin	0.000147043
#
# featur	0.000146904
#
# tanker	0.000146767
#
# score	0.000146426
#
# winner	0.000146403
#
# mine	0.000146357
#
# squar	0.000146306
#
# fellow	0.000146085
#
# provi	0.000145949
#
# viru	0.000145935
#
# essenti	0.000145742
#
# survivor	0.000145298
#
# nato	0.000145252
#
# r	0.00014521
#
# match	0.000145192
#
# petroleum	0.000145095
#
# suspend	0.000145066
#
# cell	0.000144867
#
# rocket	0.000144686
#
# ceremoni	0.000144308
#
# acquisit	0.000144249
#
# color	0.000144145
#
# drink	0.000144089
#
# manhattan	0.000144073
#
# player	0.000144005
#
# swiss	0.000143896
#
# track	0.000143837
#
# presenc	0.000143749
#
# flag	0.000143656
#
# intent	0.000143655
#
# career	0.000143589
#
# strateg	0.000143226
#
# obtain	0.000143002
#
# profess	0.000142821
#
# kidnap	0.000142764
#
# spain	0.000142689
#
# audienc	0.000142411
#
# hong	0.000142334
#
# goal	0.000142289
#
# buyout	0.000142158
#
# halt	0.000141941
#
# clash	0.000141937
#
# percentag	0.000141869
#
# earthquak	0.00014173
#
# notic	0.000141564
#
# twice	0.000141248
#
# attent	0.000141172
#
# factori	0.000141154
#
# fast	0.000141111
#
# venu	0.000141031
#
# intellig	0.000140773
#
# transit	0.000140674
#
# borrow	0.000140574
#
# baghdad	0.000140552
#
# bag	0.000140386
#
# opinion	0.000140233
#
# escap	0.000139727
#
# video	0.00013963
#
# traffic	0.00013958
#
# technic	0.000139422
#
# tabl	0.000139412
#
# thrift	0.000139333
#
# marri	0.00013913
#
# taxpay	0.000139109
#
# choic	0.000138945
#
# relationship	0.000138896
#
# alcohol	0.000138523
#
# driver	0.000138506
#
# clearli	0.000138344
#
# fort	0.000138292
#
# extrem	0.00013829
#
# instal	0.000138264
#
# substanti	0.000138167
#
# abil	0.000138148
#
# prosecut	0.000138096
#
# troy	0.000137939
#
# desert	0.00013784
#
# procedur	0.000137695
#
# complex	0.000137537
#
# dalla	0.000137238
#
# regist	0.000137141
#
# solut	0.000137073
#
# bit	0.000137025
#
# jack	0.000136697
#
# anniversari	0.000136541
#
# quayl	0.000136509
#
# iowa	0.000136373
#
# altern	0.000136366
#
# submit	0.000136316
#
# philadelphia	0.000136269
#
# mandela	0.000135984
#
# ten	0.000135922
#
# india	0.000135588
#
# restructur	0.000135335
#
# directli	0.000135325
#
# dan	0.000135208
#
# seiz	0.000135203
#
# drought	0.000135086
#
# youth	0.000135061
#
# tear	0.000135035
#
# broker	0.000135008
#
# moder	0.000134847
#
# beat	0.00013474
#
# artist	0.000134692
#
# tom	0.00013468
#
# quak	0.000134543
#
# kong	0.000134369
#
# carrier	0.000134339
#
# nd	0.000134121
#
# stephen	0.000133839
#
# exerci	0.000133634
#
# deposit	0.000133617
#
# rent	0.00013361
#
# box	0.000133598
#
# ray	0.00013348
#
# gang	0.000133474
#
# belong	0.000133288
#
# immun	0.000133005
#
# lawrenc	0.000132856
#
# green	0.000132789
#
# conflict	0.000132725
#
# jersey	0.000132652
#
# cook	0.000132331
#
# ballot	0.000132299
#
# russel	0.000132231
#
# stake	0.000132036
#
# walsh	0.000131769
#
# urban	0.000131662
#
# awar	0.000131507
#
# journalist	0.000131506
#
# bloom	0.00013137
#
# jackson	0.000131327
#
# havent	0.000131315
#
# exten	0.000131221
#
# satellit	0.000131092
#
# scientif	0.000131001
#
# arthur	0.000130864
#
# inherit	0.000130724
#
# absolut	0.0001307
#
# surfac	0.000130543
#
# donat	0.000130475
#
# amid	0.000130377
#
# english	0.000130335
#
# bankruptci	0.000130334
#
# aliv	0.000130083
#
# modern	0.000130063
#
# grew	0.00012996
#
# andrew	0.000129937
#
# plung	0.0001299
#
# rare	0.000129853
#
# canadian	0.000129827
#
# mari	0.000129567
#
# garden	0.000129557
#
# minimum	0.000129544
#
# steel	0.000129441
#
# stone	0.000129341
#
# w	0.000129329
#
# cold	0.00012898
#
# appropri	0.000128973
#
# ring	0.000128872
#
# frank	0.00012876
#
# teach	0.000128723
#
# imag	0.000128667
#
# chip	0.000128663
#
# mount	0.000128604
#
# mexican	0.0001285
#
# leak	0.000128328
#
# bargain	0.000128277
#
# hall	0.000128251
#
# reaction	0.000128236
#
# bed	0.000128225
#
# fifth	0.000128075
#
# mention	0.000128063
#
# arizona	0.000127879
#
# va	0.000127804
#
# lock	0.000127754
#
# user	0.000127601
#
# struck	0.000127399
#
# scale	0.000127383
#
# rout	0.000127092
#
# edg	0.000126978
#
# owen	0.000126904
#
# leftist	0.000126741
#
# digit	0.000126728
#
# upri	0.000126614
#
# reveal	0.00012645
#
# prize	0.000126417
#
# beirut	0.000126364
#
# gunmen	0.000126343
#
# statist	0.00012632
#
# bentsen	0.000126234
#
# cuba	0.000126208
#
# compromi	0.00012619
#
# oppon	0.000126091
#
# option	0.00012598
#
# surg	0.000125976
#
# roll	0.000125534
#
# adult	0.00012535
#
# miami	0.000125151
#
# oust	0.000124481
#
# circuit	0.000124305
#
# concert	0.000124183
#
# compet	0.000123903
#
# colleagu	0.000123867
#
# prai	0.000123849
#
# mar	0.000123687
#
# panamanian	0.000123655
#
# robertson	0.000123628
#
# dri	0.000123565
#
# prefer	0.000123512
#
# slip	0.000123489
#
# hair	0.000123457
#
# scheme	0.000123456
#
# domin	0.00012326
#
# client	0.00012313
#
# pittsburgh	0.000122944
#
# chain	0.000122719
#
# nyse	0.000122688
#
# petit	0.00012252
#
# harvest	0.00012237
#
# advic	0.00012226
#
# fighter	0.000122066
#
# god	0.000122003
#
# detect	0.000121773
#
# paint	0.000121604
#
# perman	0.000121446
#
# farmland	0.00012139
#
# inventori	0.00012122
#
# explor	0.000121141
#
# attribut	0.000121111
#
# advoc	0.000121
#
# mistak	0.00012089
#
# spacecraft	0.000120617
#
# use	0.000120487
#
# conver	0.000120441
#
# shift	0.000120432
#
# dougla	0.000120409
#
# pollut	0.000120198
#
# deadlin	0.000120111
#
# sort	0.000120105
#
# interior	0.000120078
#
# ultim	0.000119926
#
# enemi	0.000119924
#
# certainli	0.000119878
#
# bear	0.000119842
#
# railroad	0.000119777
#
# iranian	0.000119746
#
# emperor	0.000119719
#
# allegedli	0.000119718
#
# medicin	0.00011969
#
# disappoint	0.000119579
#
# fbi	0.000119409
#
# planet	0.000119185
#
# col	0.000119111
#
# charact	0.000119079
#
# trend	0.000118925
#
# d	0.000118808
#
# sleep	0.000118766
#
# mercantil	0.000118563
#
# mitchel	0.000118514
#
# add	0.000118489
#
# allianc	0.000118428
#
# respect	0.000118268
#
# global	0.000118237
#
# vietnam	0.000118225
#
# jose	0.000118117
#
# shown	0.000118033
#
# wear	0.000117896
#
# feed	0.000117691
#
# carolina	0.000117604
#
# sexual	0.00011758
#
# verdict	0.000117361
#
# harri	0.000117306
#
# veteran	0.000117286
#
# scienc	0.000117267
#
# motiv	0.000116981
#
# ireland	0.000116955
#
# babi	0.000116953
#
# stabil	0.000116918
#
# tough	0.000116894
#
# appl	0.00011684
#
# corrupt	0.000116804
#
# rev	0.000116773
#
# shout	0.000116765
#
# moment	0.000116738
#
# kasparov	0.000116549
#
# sampl	0.000116485
#
# strengthen	0.000116168
#
# plot	0.000116103
#
# disappear	0.000116032
#
# type	0.000116013
#
# plo	0.000115973
#
# attract	0.000115957
#
# particular	0.000115899
#
# sikh	0.000115821
#
# fred	0.000115752
#
# net	0.000115702
#
# chamber	0.0001156
#
# attitud	0.000115418
#
# probe	0.000115262
#
# caught	0.000115259
#
# antonio	0.000115242
#
# egypt	0.000115237
#
# nixon	0.000115229
#
# chair	0.000115131
#
# graduat	0.000115023
#
# coup	0.000114837
#
# cloth	0.000114753
#
# boe	0.000114706
#
# automat	0.000114636
#
# titl	0.000114599
#
# pursu	0.00011444
#
# equal	0.000114285
#
# highway	0.00011428
#
# moral	0.000114251
#
# relief	0.000114221
#
# repli	0.000114077
#
# p	0.000114062
#
# legislatur	0.000113908
#
# giant	0.000113885
#
# ali	0.000113587
#
# split	0.000113464
#
# tactic	0.00011343
#
# platform	0.000113394
#
# afford	0.000113214
#
# demjanjuk	0.000112998
#
# simon	0.000112964
#
# fulli	0.000112868
#
# radar	0.000112837
#
# resum	0.000112813
#
# funer	0.000112806
#
# nicaragua	0.000112794
#
# error	0.000112736
#
# impress	0.000112665
#
# neg	0.000112657
#
# discount	0.00011264
#
# manuel	0.000112607
#
# highli	0.000112582
#
# cigarett	0.000112515
#
# shield	0.000112467
#
# palac	0.000112233
#
# master	0.000112203
#
# gilbert	0.000112108
#
# steve	0.000111936
#
# eat	0.000111769
#
# anticip	0.000111439
#
# recogn	0.000111276
#
# bureau	0.000111246
#
# telescop	0.00011121
#
# notifi	0.000111098
#
# su	0.000110997
#
# dakota	0.000110884
#
# maxwel	0.000110724
#
# socialist	0.000110598
#
# ethnic	0.000110447
#
# costa	0.000110409
#
# elector	0.000110343
#
# seal	0.000110193
#
# howard	0.000110119
#
# shipment	0.000110099
#
# captur	0.000109986
#
# coloni	0.000109926
#
# custodi	0.00010987
#
# nelson	0.000109803
#
# van	0.00010975
#
# consist	0.000109747
#
# conspiraci	0.000109633
#
# parol	0.000109499
#
# explod	0.000109452
#
# gephardt	0.000109172
#
# freed	0.000109021
#
# kansa	0.000108943
#
# card	0.000108599
#
# baltimor	0.000108372
#
# feloni	0.0001083
#
# usda	0.000108149
#
# capac	0.000108141
#
# steven	0.000108067
#
# capitol	0.000108025
#
# wing	0.000107939
#
# theft	0.000107506
#
# suburb	0.00010738
#
# expir	0.000107366
#
# hang	0.000107332
#
# gotten	0.000107256
#
# thunderstorm	0.000107256
#
# ann	0.000107229
#
# speaker	0.000107185
#
# medal	0.000106971
#
# behalf	0.000106851
#
# worst	0.000106744
#
# ny	0.000106687
#
# pack	0.000106513
#
# mainli	0.000106405
#
# naval	0.000106201
#
# ltd	0.000106181
#
# denver	0.000105989
#
# walesa	0.000105971
#
# shock	0.000105779
#
# capabl	0.000105751
#
# pose	0.000105728
#
# method	0.000105719
#
# roof	0.000105688
#
# broad	0.000105638
#
# hamilton	0.000105555
#
# massiv	0.000105549
#
# purpo	0.000105291
#
# sun	0.00010527
#
# canada	0.000105084
#
# superior	0.000104974
#
# motion	0.00010484
#
# missouri	0.000104774
#
# elderli	0.000104708
#
# trump	0.000104705
#
# possess	0.00010466
#
# dramat	0.00010454
#
# gm	0.000104521
#
# buyer	0.000104434
#
# banker	0.000104385
#
# contin	0.000104209
#
# writer	0.000104161
#
# enjoy	0.000104026
#
# abroad	0.000103944
#
# arent	0.000103752
#
# scatter	0.000103702
#
# invad	0.000103681
#
# hezbollah	0.000103457
#
# politician	0.000103414
#
# barbara	0.000103347
#
# impeach	0.000103221
#
# frequent	0.000102925
#
# sharp	0.00010292
#
# walter	0.000102781
#
# stress	0.000102748
#
# maker	0.00010265
#
# strongli	0.000102542
#
# thatcher	0.000102475
#
# actress	0.000102322
#
# sweep	0.000102301
#
# unif	0.000102251
#
# allen	0.000102085
#
# socal	0.00010202
#
# plastic	0.000101924
#
# ice	0.000101769
#
# vatican	0.000101696
#
# qualiti	0.000101686
#
# russian	0.000101492
#
# partli	0.000101418
#
# murphi	0.000101418
#
# aquino	0.000101392
#
# humphrey	0.00010137
#
# lowest	0.000101342
#
# warm	0.000101321
#
# surround	0.000101309
#
# arafat	0.000101308
#
# wor	0.000101257
#
# nunn	0.000101095
#
# creek	0.000101087
#
# dog	0.000100995
#
# souter	0.000100979
#
# worldwid	0.000100682
#
# pace	0.000100656
#
# wi	0.00010064
#
# harvard	0.000100602
#
# craft	0.000100516
#
# ear	0.000100445
#
# except	0.000100399
#
# outnumb	0.000100391
#
# shut	0.000100317
#
# renew	0.000100305
#
# convinc	0.00010028
#
# birthday	0.000100196
#
# foundat	0.000100146
#
# repeatedli	9.99802e-05
#
# bay	9.99523e-05
#
# straight	9.97429e-05
#
# fundament	9.97196e-05
#
# listen	9.96955e-05
#
# tower	9.96838e-05
#
# touch	9.96777e-05
#
# louisiana	9.95724e-05
#
# rush	9.94745e-05
#
# realiz	9.94001e-05
#
# bone	9.89493e-05
#
# overnight	9.89359e-05
#
# aviat	9.89022e-05
#
# discrimin	9.87918e-05
#
# glass	9.87527e-05
#
# roger	9.87247e-05
#
# bomber	9.8657e-05
#
# revolut	9.86147e-05
#
# jordan	9.8413e-05
#
# drill	9.83898e-05
#
# deduct	9.83734e-05
#
# sing	9.83104e-05
#
# ozon	9.82629e-05
#
# disclosur	9.80281e-05
#
# journal	9.80112e-05
#
# sweden	9.80081e-05
#
# orbit	9.79483e-05
#
# regular	9.78784e-05
#
# bloc	9.78235e-05
#
# judgment	9.78152e-05
#
# slay	9.77878e-05
#
# compen	9.77794e-05
#
# n	9.74865e-05
#
# throw	9.73281e-05
#
# lobbi	9.72849e-05
#
# subsidi	9.71426e-05
#
# shape	9.71128e-05
#
# asia	9.69546e-05
#
# pa	9.69204e-05
#
# tension	9.6839e-05
#
# georgia	9.65422e-05
#
# morgan	9.64954e-05
#
# plc	9.63239e-05
#
# warren	9.62621e-05
#
# sailor	9.62536e-05
#
# chess	9.61331e-05
#
# pain	9.60475e-05
#
# pennsylvania	9.60253e-05
#
# succeed	9.60078e-05
#
# experienc	9.59813e-05
#
# bradley	9.58606e-05
#
# exactli	9.57778e-05
#
# map	9.57113e-05
#
# irancontra	9.56848e-05
#
# version	9.55414e-05
#
# oklahoma	9.5521e-05
#
# mortgag	9.55089e-05
#
# chosen	9.53818e-05
#
# discourag	9.53572e-05
#
# frozen	9.52777e-05
#
# pekin	9.52659e-05
#
# repair	9.52419e-05
#
# atmosph	9.51217e-05
#
# publicli	9.50956e-05
#
# alabama	9.50837e-05
#
# contest	9.49069e-05
#
# entertain	9.45704e-05
#
# longterm	9.43842e-05
#
# window	9.43468e-05
#
# util	9.41452e-05
#
# anderson	9.40324e-05
#
# alien	9.39609e-05
#
# reportedli	9.39603e-05
#
# oversea	9.38605e-05
#
# weight	9.36099e-05
#
# femal	9.35612e-05
#
# upper	9.35409e-05
#
# hasnt	9.35135e-05
#
# denni	9.34421e-05
#
# slain	9.34083e-05
#
# salari	9.3397e-05
#
# faster	9.3151e-05
#
# cheer	9.31045e-05
#
# endor	9.30263e-05
#
# difficulti	9.27966e-05
#
# juror	9.2701e-05
#
# athlet	9.26875e-05
#
# ibm	9.26363e-05
#
# owe	9.26285e-05
#
# leagu	9.25241e-05
#
# dissid	9.24634e-05
#
# rocki	9.2391e-05
#
# gene	9.23095e-05
#
# morri	9.22054e-05
#
# monetari	9.21654e-05
#
# syndrom	9.20303e-05
#
# fernandez	9.19921e-05
#
# hondura	9.19453e-05
#
# poland	9.19429e-05
#
# deport	9.19402e-05
#
# grave	9.19062e-05
#
# robberi	9.19056e-05
#
# switch	9.1694e-05
#
# mike	9.14299e-05
#
# oliv	9.12204e-05
#
# increasingli	9.11947e-05
#
# holiday	9.11647e-05
#
# drag	9.11413e-05
#
# hide	9.11185e-05
#
# southeast	9.0952e-05
#
# veto	9.09353e-05
#
# minnesota	9.07793e-05
#
# bottom	9.06846e-05
#
# drove	9.0647e-05
#
# unusu	9.0614e-05
#
# engag	9.06103e-05
#
# automobil	9.04263e-05
#
# princ	9.03357e-05
#
# storag	9.02369e-05
#
# dinner	9.02357e-05
#
# shortag	9.02008e-05
#
# philosophi	9.00445e-05
#
# exclud	9.00406e-05
#
# birth	8.99943e-05
#
# apartheid	8.9848e-05
#
# shultz	8.98422e-05
#
# royal	8.98421e-05
#
# marshal	8.98405e-05
#
# trigger	8.98368e-05
#
# fundamentalist	8.9803e-05
#
# guest	8.97828e-05
#
# wash	8.97253e-05
#
# jerusalem	8.97208e-05
#
# mental	8.96983e-05
#
# colorado	8.96889e-05
#
# extra	8.96855e-05
#
# rifl	8.96747e-05
#
# brook	8.9672e-05
#
# edwin	8.96579e-05
#
# charter	8.95485e-05
#
# promin	8.95407e-05
#
# condemn	8.95184e-05
#
# concentr	8.94485e-05
#
# rape	8.94172e-05
#
# id	8.93591e-05
#
# preliminari	8.93109e-05
#
# prioriti	8.92504e-05
#
# yeutter	8.921e-05
#
# cheney	8.91813e-05
#
# welfar	8.90909e-05
#
# amnesti	8.90253e-05
#
# physic	8.89855e-05
#
# simpli	8.89006e-05
#
# easi	8.88992e-05
#
# tent	8.88849e-05
#
# hildreth	8.88193e-05
#
# metropolitan	8.85821e-05
#
# richter	8.85241e-05
#
# stadium	8.85073e-05
#
# recoveri	8.84893e-05
#
# postal	8.84105e-05
#
# vacat	8.8396e-05
#
# flew	8.83593e-05
#
# ventur	8.82293e-05
#
# one	8.82127e-05
#
# youv	8.81393e-05
#
# marijuana	8.81195e-05
#
# controversi	8.78211e-05
#
# coverag	8.76375e-05
#
# karpov	8.76229e-05
#
# bruce	8.75909e-05
#
# ought	8.75586e-05
#
# oat	8.75471e-05
#
# afraid	8.73818e-05
#
# ethic	8.73097e-05
#
# depress	8.72668e-05
#
# anc	8.72435e-05
#
# analysi	8.71523e-05
#
# chamorro	8.71288e-05
#
# specialist	8.69969e-05
#
# policeman	8.69106e-05
#
# ocean	8.68006e-05
#
# interv	8.6774e-05
#
# entri	8.67e-05
#
# dividend	8.66917e-05
#
# brain	8.66916e-05
#
# academi	8.65254e-05
#
# fresh	8.6472e-05
#
# auction	8.63116e-05
#
# chariti	8.61605e-05
#
# seoul	8.60461e-05
#
# wed	8.60044e-05
#
# harm	8.59949e-05
#
# crack	8.59917e-05
#
# rightw	8.59024e-05
#
# shell	8.58524e-05
#
# jesu	8.58022e-05
#
# fal	8.57802e-05
#
# concess	8.57459e-05
#
# unidentifi	8.56529e-05
#
# solv	8.54541e-05
#
# solid	8.54356e-05
#
# nice	8.54243e-05
#
# ed	8.53202e-05
#
# henson	8.52665e-05
#
# marlin	8.52569e-05
#
# wonder	8.51887e-05
#
# cri	8.51319e-05
#
# drawn	8.5015e-05
#
# alert	8.5003e-05
#
# rsqb	8.49706e-05
#
# expan	8.49009e-05
#
# blast	8.47722e-05
#
# hardlin	8.46713e-05
#
# elig	8.4653e-05
#
# alan	8.46205e-05
#
# tropic	8.45235e-05
#
# barrier	8.45062e-05
#
# overthecount	8.44513e-05
#
# adverti	8.4408e-05
#
# hunter	8.44053e-05
#
# coastal	8.43504e-05
#
# juan	8.43018e-05
#
# policemen	8.426e-05
#
# livestock	8.42434e-05
#
# midnight	8.42258e-05
#
# shower	8.4138e-05
#
# daniel	8.40017e-05
#
# suburban	8.39658e-05
#
# super	8.38876e-05
#
# junk	8.37193e-05
#
# midwest	8.37128e-05
#
# grown	8.37054e-05
#
# symbol	8.36546e-05
#
# militia	8.35986e-05
#
# reynold	8.35591e-05
#
# assassin	8.34318e-05
#
# gnp	8.34081e-05
#
# spectat	8.32923e-05
#
# output	8.32842e-05
#
# ap	8.32828e-05
#
# reopen	8.32469e-05
#
# discoveri	8.31281e-05
#
# languag	8.30981e-05
#
# visitor	8.30414e-05
#
# montana	8.30354e-05
#
# tumbl	8.29854e-05
#
# carter	8.2904e-05
#
# ronald	8.27266e-05
#
# camera	8.26682e-05
#
# jerri	8.26192e-05
#
# prohibit	8.25598e-05
#
# smuggl	8.25471e-05
#
# bell	8.24909e-05
#
# gaza	8.23537e-05
#
# quick	8.23404e-05
#
# lebanon	8.23124e-05
#
# strategi	8.21834e-05
#
# australia	8.21399e-05
#
# truth	8.208e-05
#
# utah	8.19862e-05
#
# cnn	8.19804e-05
#
# solidar	8.19323e-05
#
# meat	8.18355e-05
#
# cloudi	8.18346e-05
#
# balanc	8.18344e-05
#
# clark	8.17847e-05
#
# monet	8.16612e-05
#
# assign	8.15976e-05
#
# definit	8.15882e-05
#
# sick	8.15843e-05
#
# fan	8.1475e-05
#
# stolen	8.14422e-05
#
# uss	8.14331e-05
#
# mich	8.14275e-05
#
# poindext	8.14124e-05
#
# koch	8.13932e-05
#
# coal	8.13361e-05
#
# imposs	8.13251e-05
#
# dispatch	8.12969e-05
#
# harass	8.12672e-05
#
# usual	8.11676e-05
#
# monthli	8.09598e-05
#
# younger	8.07378e-05
#
# tender	8.06904e-05
#
# bail	8.06772e-05
#
# ignor	8.06672e-05
#
# belief	8.06374e-05
#
# faith	8.0626e-05
#
# loser	8.0514e-05
#
# gate	8.04318e-05
#
# supervi	8.03865e-05
#
# recruit	8.03843e-05
#
# cargo	8.03831e-05
#
# choo	8.0317e-05
#
# patrick	8.00837e-05
#
# stab	8.00438e-05
#
# path	7.9953e-05
#
# modest	7.99454e-05
#
# spanish	7.98986e-05
#
# regim	7.98431e-05
#
# typic	7.9834e-05
#
# champion	7.98312e-05
#
# premier	7.98214e-05
#
# resort	7.97211e-05
#
# klerk	7.96622e-05
#
# accompani	7.96531e-05
#
# physician	7.96456e-05
#
# municip	7.962e-05
#
# ira	7.95348e-05
#
# michigan	7.94954e-05
#
# coordin	7.94814e-05
#
# soar	7.94591e-05
#
# trace	7.92964e-05
#
# blaze	7.92319e-05
#
# fix	7.91525e-05
#
# mate	7.91365e-05
#
# egyptian	7.91326e-05
#
# greatest	7.90985e-05
#
# tenness	7.90723e-05
#
# hispan	7.89654e-05
#
# simpl	7.89254e-05
#
# dick	7.87273e-05
#
# yellow	7.86729e-05
#
# reput	7.86177e-05
#
# airplan	7.85903e-05
#
# conclu	7.85814e-05
#
# categori	7.85294e-05
#
# geneva	7.83896e-05
#
# terri	7.8384e-05
#
# instruct	7.83249e-05
#
# poison	7.81739e-05
#
# varieti	7.78818e-05
#
# vital	7.78698e-05
#
# scandal	7.76513e-05
#
# signatur	7.75081e-05
#
# style	7.74982e-05
#
# skin	7.749e-05
#
# dream	7.74123e-05
#
# tobacco	7.73206e-05
#
# joe	7.72939e-05
#
# conc	7.72407e-05
#
# carlo	7.72088e-05
#
# outlook	7.71589e-05
#
# bc	7.7116e-05
#
# weaken	7.69376e-05
#
# grumman	7.69187e-05
#
# anger	7.69046e-05
#
# algeria	7.6764e-05
#
# counter	7.66103e-05
#
# idaho	7.65944e-05
#
# batteri	7.64946e-05
#
# poem	7.64897e-05
#
# kremlin	7.63018e-05
#
# connecticut	7.62172e-05
#
# lewi	7.60087e-05
#
# behavior	7.59793e-05
#
# shoulder	7.59521e-05
#
# taylor	7.59271e-05
#
# screen	7.58946e-05
#
# hijack	7.58936e-05
#
# priest	7.58907e-05
#
# maximum	7.57122e-05
#
# magnitud	7.57093e-05
#
# rich	7.55918e-05
#
# enact	7.55589e-05
#
# sl	7.55147e-05
#
# function	7.55135e-05
#
# creditor	7.54419e-05
#
# fought	7.54172e-05
#
# rememb	7.5409e-05
#
# nativ	7.5408e-05
#
# probat	7.53441e-05
#
# kentucki	7.53263e-05
#
# meant	7.52645e-05
#
# peninsula	7.52492e-05
#
# therapi	7.52314e-05
#
# czechoslovakia	7.51945e-05
#
# g	7.51799e-05
#
# fda	7.51377e-05
#
# pension	7.50999e-05
#
# principl	7.50575e-05
#
# nauvoo	7.50128e-05
#
# boom	7.49881e-05
#
# disagr	7.49368e-05
#
# liquid	7.48608e-05
#
# tourist	7.46573e-05
#
# mariel	7.46236e-05
#
# mainten	7.45789e-05
#
# emigr	7.45176e-05
#
# toll	7.44975e-05
#
# bcspehealth	7.44906e-05
#
# inten	7.44853e-05
#
# knowledg	7.44816e-05
#
# adjust	7.44773e-05
#
# arkansa	7.43798e-05
#
# dutch	7.43491e-05
#
# stronger	7.43017e-05
#
# edt	7.426e-05
#
# magistr	7.41979e-05
#
# durenberg	7.41757e-05
#
# nc	7.41524e-05
#
# decr	7.4143e-05
#
# alaska	7.41143e-05
#
# christ	7.40825e-05
#
# lloyd	7.40371e-05
#
# inquiri	7.38874e-05
#
# interst	7.38688e-05
#
# exchangelist	7.38561e-05
#
# embargo	7.38239e-05
#
# ortega	7.37839e-05
#
# aspect	7.37583e-05
#
# cemeteri	7.36821e-05
#
# nur	7.36747e-05
#
# exceed	7.36704e-05
#
# larri	7.36038e-05
#
# brand	7.35923e-05
#
# flow	7.35646e-05
#
# blow	7.35429e-05
#
# fiveyear	7.34964e-05
#
# premium	7.34907e-05
#
# homosexu	7.34233e-05
#
# host	7.33939e-05
#
# leg	7.33585e-05
#
# sat	7.33512e-05
#
# wareh	7.32276e-05
#
# correspond	7.32236e-05
#
# liabil	7.31468e-05
#
# theyv	7.31359e-05
#
# township	7.31069e-05
#
# defect	7.30881e-05
#
# elabor	7.30705e-05
#
# wilson	7.29834e-05
#
# hazard	7.28334e-05
#
# cuomo	7.2762e-05
#
# ward	7.27599e-05
#
# tire	7.27041e-05
#
# swim	7.26982e-05
#
# wildlif	7.26934e-05
#
# rubi	7.26904e-05
#
# milit	7.26748e-05
#
# counselor	7.26722e-05
#
# divorc	7.26138e-05
#
# bottl	7.24737e-05
#
# golden	7.24653e-05
#
# briefli	7.24495e-05
#
# builder	7.23698e-05
#
# mechan	7.23687e-05
#
# membership	7.23217e-05
#
# achiev	7.21993e-05
#
# superpow	7.21729e-05
#
# outcom	7.21409e-05
#
# preserv	7.21329e-05
#
# salvador	7.20658e-05
#
# theme	7.20227e-05
#
# hale	7.18442e-05
#
# bullet	7.17994e-05
#
# lsqb	7.17613e-05
#
# stood	7.16937e-05
#
# ralph	7.16826e-05
#
# stem	7.15675e-05
#
# billboard	7.14943e-05
#
# threw	7.14637e-05
#
# sky	7.13394e-05
#
# longtim	7.13339e-05
#
# imprison	7.13119e-05
#
# dark	7.12853e-05
#
# handgun	7.12075e-05
#
# realiti	7.11808e-05
#
# edit	7.11354e-05
#
# display	7.11047e-05
#
# surgeon	7.1074e-05
#
# wish	7.10641e-05
#
# divid	7.07541e-05
#
# cautiou	7.06233e-05
#
# roh	7.05765e-05
#
# nevada	7.05649e-05
#
# routin	7.0478e-05
#
# conn	7.0416e-05
#
# margin	7.04008e-05
#
# tip	7.03836e-05
#
# drew	7.0151e-05
#
# basement	7.00914e-05
#
# upheld	7.00536e-05
#
# load	7.00285e-05
#
# angri	6.99345e-05
#
# takeshita	6.98685e-05
#
# ride	6.9866e-05
#
# k	6.97818e-05
#
# dam	6.97761e-05
#
# hero	6.97549e-05
#
# egg	6.97274e-05
#
# traffick	6.96876e-05
#
# prayer	6.96321e-05
#
# ag	6.95886e-05
#
# lunch	6.95764e-05
#
# hole	6.95545e-05
#
# nicaraguan	6.93941e-05
#
# elev	6.92716e-05
#
# techniqu	6.9198e-05
#
# stanley	6.91209e-05
#
# ...
#
# twohour	9.40397e-06
#
# destini	9.38224e-06
#
# hilton	9.37287e-06
#
# diana	9.36039e-06
#
# rude	9.35241e-06
#
# graviti	9.34608e-06
#
# albrecht	9.34246e-06
#
# visibl	9.33631e-06
#
# suarez	9.32774e-06
#
# rewrit	9.32696e-06
#
# raft	9.32601e-06
#
# secular	9.32514e-06
#
# sixteen	9.31718e-06
#
# romanc	9.30821e-06
#
# xinhua	9.30651e-06
#
# crocodil	9.29729e-06
#
# lightn	9.297e-06
#
# wang	9.29284e-06
#
# paramilitari	9.29003e-06
#
# hose	9.27976e-06
#
# romant	9.26215e-06
#
# ntsb	9.25528e-06
#
# anni	9.25202e-06
#
# passion	9.24377e-06
#
# boeski	9.23806e-06
#
# gull	9.22795e-06
#
# mess	9.21661e-06
#
# exploit	9.20533e-06
#
# attir	9.19662e-06
#
# beyer	9.18574e-06
#
# architectur	9.18474e-06
#
# jeopardi	9.17856e-06
#
# notif	9.16845e-06
#
# servant	9.16382e-06
#
# judith	9.16379e-06
#
# stark	9.15076e-06
#
# selloff	9.13749e-06
#
# buddi	9.13475e-06
#
# partisan	9.12298e-06
#
# pour	9.11391e-06
#
# plutonium	9.112e-06
#
# coleman	9.1088e-06
#
# marietta	9.10293e-06
#
# sharpest	9.0988e-06
#
# ordnanc	9.09268e-06
#
# misunderstand	9.09197e-06
#
# summon	9.0911e-06
#
# thwart	9.08977e-06
#
# precinct	9.08404e-06
#
# silverman	9.05708e-06
#
# hakim	9.05673e-06
#
# mohammad	9.05082e-06
#
# toughest	9.04634e-06
#
# easter	9.04522e-06
#
# wynberg	9.03767e-06
#
# doyl	9.03755e-06
#
# outdoor	9.03508e-06
#
# showca	9.0304e-06
#
# ventura	9.02725e-06
#
# finland	8.9905e-06
#
# refrain	8.98574e-06
#
# detector	8.98489e-06
#
# lifestyl	8.96739e-06
#
# sipan	8.94993e-06
#
# holyok	8.94702e-06
#
# menorah	8.94465e-06
#
# faber	8.9424e-06
#
# nicola	8.93715e-06
#
# shaki	8.93252e-06
#
# mead	8.92909e-06
#
# cocoa	8.9206e-06
#
# lash	8.91767e-06
#
# langley	8.91203e-06
#
# hart	8.9105e-06
#
# marino	8.9086e-06
#
# teller	8.90451e-06
#
# wellston	8.89577e-06
#
# aft	8.89563e-06
#
# raton	8.88654e-06
#
# paperwork	8.8835e-06
#
# abbott	8.87992e-06
#
# danni	8.8727e-06
#
# berkeley	8.86296e-06
#
# solomon	8.85875e-06
#
# yugoslav	8.83557e-06
#
# rhode	8.81877e-06
#
# santiago	8.80272e-06
#
# disorderli	8.76935e-06
#
# julio	8.7666e-06
#
# satisfactori	8.76638e-06
#
# compil	8.75629e-06
#
# saito	8.75178e-06
#
# ernest	8.73776e-06
#
# arraign	8.71671e-06
#
# pyongyang	8.71046e-06
#
# crandal	8.70857e-06
#
# cordon	8.7072e-06
#
# wellwish	8.70064e-06
#
# kirk	8.69651e-06
#
# propul	8.68908e-06
#
# copper	8.67009e-06
#
# dull	8.66548e-06
#
# unregul	8.66462e-06
#
# burlington	8.66371e-06
#
# finley	8.65e-06
#
# shah	8.64892e-06
#
# prudentialbach	8.6472e-06
#
# dwayn	8.64718e-06
#
# volcano	8.64625e-06
#
# sake	8.64277e-06
#
# putnam	8.63507e-06
#
# jeopard	8.63464e-06
#
# epic	8.62767e-06
#
# mislead	8.62564e-06
#
# toss	8.62049e-06
#
# woodi	8.60312e-06
#
# pavlov	8.60145e-06
#
# boschwitz	8.59101e-06
#
# float	8.58996e-06
#
# surprisingli	8.58753e-06
#
# parenthood	8.57888e-06
#
# plessey	8.57462e-06
#
# rafsanjani	8.54862e-06
#
# shorter	8.52235e-06
#
# logan	8.51884e-06
#
# passiv	8.51163e-06
#
# hoan	8.50954e-06
#
# diari	8.50689e-06
#
# eugen	8.50165e-06
#
# rioter	8.50082e-06
#
# lorimar	8.5006e-06
#
# downturn	8.48892e-06
#
# hatch	8.48729e-06
#
# harlem	8.48533e-06
#
# autumn	8.48505e-06
#
# crequ	8.47367e-06
#
# notion	8.466e-06
#
# repatri	8.46091e-06
#
# repress	8.45989e-06
#
# notebook	8.45979e-06
#
# hubert	8.44032e-06
#
# duncan	8.42835e-06
#
# accel	8.42631e-06
#
# crystal	8.41549e-06
#
# livingston	8.40961e-06
#
# tariq	8.40851e-06
#
# burleson	8.39549e-06
#
# khashoggi	8.39452e-06
#
# scottish	8.33364e-06
#
# nestl	8.30628e-06
#
# teen	8.30229e-06
#
# cohost	8.30052e-06
#
# talent	8.25596e-06
#
# enril	8.24825e-06
#
# hunthausen	8.23636e-06
#
# bella	8.23091e-06
#
# robbi	8.22514e-06
#
# hover	8.21185e-06
#
# rubin	8.20703e-06
#
# nida	8.19849e-06
#
# clay	8.1955e-06
#
# bergland	8.19381e-06
#
# archer	8.18016e-06
#
# womb	8.16775e-06
#
# slapp	8.15243e-06
#
# okla	8.15091e-06
#
# ramstein	8.13441e-06
#
# joaquin	8.0961e-06
#
# wilburi	8.09448e-06
#
# abdul	8.08646e-06
#
# insolv	8.06457e-06
#
# outreach	8.06348e-06
#
# hodel	8.05748e-06
#
# veterinarian	8.05335e-06
#
# diversifi	8.03389e-06
#
# laughter	8.02929e-06
#
# merc	8.02626e-06
#
# ambul	8.0216e-06
#
# fractur	8.01449e-06
#
# dawkin	8.0067e-06
#
# stunt	8.00479e-06
#
# hamper	7.99955e-06
#
# edgar	7.99604e-06
#
# uncomfort	7.99318e-06
#
# dad	7.99259e-06
#
# certainti	7.99034e-06
#
# iliescu	7.98847e-06
#
# stallon	7.98842e-06
#
# aftershock	7.97167e-06
#
# mydland	7.94053e-06
#
# presser	7.93768e-06
#
# nsc	7.91592e-06
#
# hartford	7.91052e-06
#
# conveni	7.90815e-06
#
# midshipman	7.89946e-06
#
# grandson	7.8877e-06
#
# leo	7.88229e-06
#
# daisi	7.85944e-06
#
# launder	7.84231e-06
#
# rancher	7.83306e-06
#
# authent	7.83095e-06
#
# symposium	7.83062e-06
#
# ayatollah	7.81669e-06
#
# gloomi	7.81029e-06
#
# bunch	7.80121e-06
#
# cmdr	7.80091e-06
#
# garrett	7.80002e-06
#
# upham	7.79765e-06
#
# drugrel	7.79261e-06
#
# norwegian	7.77995e-06
#
# sao	7.76229e-06
#
# recreat	7.76205e-06
#
# sidon	7.75725e-06
#
# deadlock	7.7548e-06
#
# suscept	7.75272e-06
#
# bofil	7.74701e-06
#
# brake	7.73667e-06
#
# supposedli	7.73304e-06
#
# outset	7.71639e-06
#
# heel	7.7073e-06
#
# tyler	7.70699e-06
#
# dropout	7.69474e-06
#
# ranger	7.68906e-06
#
# oman	7.67655e-06
#
# commenc	7.6713e-06
#
# mistrial	7.65627e-06
#
# sixday	7.65475e-06
#
# lacklust	7.62592e-06
#
# discretionari	7.61025e-06
#
# fa	7.60592e-06
#
# obando	7.60113e-06
#
# riversid	7.6e-06
#
# atlantaba	7.59394e-06
#
# pizza	7.58004e-06
#
# tawana	7.56741e-06
#
# auditorium	7.54769e-06
#
# vancouv	7.54348e-06
#
# gust	7.543e-06
#
# whale	7.542e-06
#
# bernardino	7.54134e-06
#
# apiec	7.53277e-06
#
# freighter	7.52704e-06
#
# presumpt	7.52233e-06
#
# eclip	7.52232e-06
#
# roe	7.51926e-06
#
# portugu	7.51479e-06
#
# bath	7.51327e-06
#
# uphold	7.50928e-06
#
# kurdish	7.50666e-06
#
# uncl	7.48186e-06
#
# coral	7.48085e-06
#
# hepat	7.47616e-06
#
# mutini	7.47353e-06
#
# resent	7.47096e-06
#
# spear	7.46159e-06
#
# peacetim	7.44806e-06
#
# descent	7.44509e-06
#
# sacramento	7.43868e-06
#
# demi	7.4157e-06
#
# ricki	7.40294e-06
#
# merci	7.39286e-06
#
# timber	7.39002e-06
#
# baguio	7.36551e-06
#
# rinfret	7.36123e-06
#
# characterist	7.35946e-06
#
# tegucigalpa	7.35378e-06
#
# planetari	7.35342e-06
#
# courag	7.34933e-06
#
# martyr	7.3488e-06
#
# roberto	7.34726e-06
#
# dissatisfact	7.33546e-06
#
# reinstat	7.33395e-06
#
# foremost	7.32951e-06
#
# palmerola	7.32271e-06
#
# aftertax	7.31788e-06
#
# repurcha	7.31677e-06
#
# tommi	7.3152e-06
#
# sauc	7.3127e-06
#
# vend	7.30898e-06
#
# outskirt	7.29965e-06
#
# standoff	7.29965e-06
#
# muscl	7.29387e-06
#
# shakeup	7.28906e-06
#
# char	7.2857e-06
#
# barash	7.27161e-06
#
# distinct	7.26301e-06
#
# vincent	7.2532e-06
#
# higgin	7.25067e-06
#
# tremor	7.24011e-06
#
# foothigh	7.23899e-06
#
# frail	7.2351e-06
#
# prop	7.21565e-06
#
# wva	7.21441e-06
#
# tenor	7.20001e-06
#
# caterpillar	7.19094e-06
#
# horror	7.19009e-06
#
# fieri	7.16173e-06
#
# bonesmen	7.15359e-06
#
# kennebunkport	7.12691e-06
#
# hub	7.12052e-06
#
# dancer	7.113e-06
#
# centenni	7.10619e-06
#
# poetri	7.09373e-06
#
# clandestin	7.05497e-06
#
# anguish	7.03649e-06
#
# princeton	7.03496e-06
#
# visual	7.02171e-06
#
# rubbish	7.01799e-06
#
# curio	7.00314e-06
#
# bolivia	7.00123e-06
#
# dali	6.98585e-06
#
# vern	6.97341e-06
#
# megamouth	6.96855e-06
#
# pulitz	6.96608e-06
#
# newsweek	6.94871e-06
#
# rundown	6.92686e-06
#
# hopp	6.91784e-06
#
# ramp	6.90013e-06
#
# analyz	6.87145e-06
#
# seismic	6.87084e-06
#
# disqualifi	6.87055e-06
#
# garri	6.85467e-06
#
# castillo	6.85019e-06
#
# sioux	6.8469e-06
#
# creativ	6.84442e-06
#
# lighter	6.81772e-06
#
# bilzerian	6.81717e-06
#
# gan	6.8074e-06
#
# salomon	6.80487e-06
#
# delic	6.80315e-06
#
# interag	6.79049e-06
#
# singh	6.77056e-06
#
# yanci	6.76289e-06
#
# overweight	6.75437e-06
#
# neglect	6.74318e-06
#
# pleasant	6.74161e-06
#
# councilman	6.74027e-06
#
# belgian	6.73564e-06
#
# rca	6.73133e-06
#
# quaker	6.72552e-06
#
# bst	6.72433e-06
#
# diaper	6.72384e-06
#
# dna	6.7199e-06
#
# sane	6.71733e-06
#
# rican	6.70917e-06
#
# gravley	6.69336e-06
#
# breakin	6.6883e-06
#
# hid	6.6774e-06
#
# avalanch	6.66155e-06
#
# skip	6.64557e-06
#
# inn	6.64507e-06
#
# prudent	6.63417e-06
#
# clyde	6.62819e-06
#
# impedi	6.5996e-06
#
# carrol	6.58619e-06
#
# bedard	6.57088e-06
#
# burt	6.55264e-06
#
# nonviol	6.52146e-06
#
# electionyear	6.51877e-06
#
# proposit	6.49974e-06
#
# lindsey	6.49844e-06
#
# chapman	6.49258e-06
#
# jorg	6.4901e-06
#
# bolt	6.48981e-06
#
# fever	6.48227e-06
#
# taipei	6.4671e-06
#
# recordkeep	6.46545e-06
#
# salli	6.44566e-06
#
# knudsen	6.4425e-06
#
# benton	6.42872e-06
#
# preacher	6.41981e-06
#
# ambush	6.39594e-06
#
# auxiliari	6.37122e-06
#
# entrap	6.37066e-06
#
# reckless	6.35502e-06
#
# vindic	6.34815e-06
#
# restitut	6.34631e-06
#
# scalper	6.33484e-06
#
# tibet	6.33178e-06
#
# payn	6.32479e-06
#
# nephew	6.31596e-06
#
# newt	6.29197e-06
#
# overrun	6.29131e-06
#
# chaney	6.29024e-06
#
# bounti	6.28682e-06
#
# travi	6.28396e-06
#
# lindsay	6.27477e-06
#
# misconduct	6.26046e-06
#
# boca	6.24752e-06
#
# instabl	6.23764e-06
#
# lui	6.21335e-06
#
# poe	6.1927e-06
#
# birendra	6.19208e-06
#
# randolph	6.18958e-06
#
# hungarian	6.18808e-06
#
# blockbust	6.18105e-06
#
# skyscrap	6.15953e-06
#
# casper	6.15609e-06
#
# quint	6.13952e-06
#
# raul	6.12757e-06
#
# circular	6.11812e-06
#
# scari	6.08688e-06
#
# greedi	6.08162e-06
#
# goodbi	6.06894e-06
#
# proxmir	6.06728e-06
#
# marbl	6.06701e-06
#
# sunk	6.05508e-06
#
# beverag	6.0493e-06
#
# mohawk	6.04915e-06
#
# progovern	6.03465e-06
#
# unicef	6.02721e-06
#
# maddox	6.01321e-06
#
# hoyt	6.00806e-06
#
# klux	6.00173e-06
#
# industrialist	6.00037e-06
#
# randomli	5.94803e-06
#
# matthew	5.94615e-06
#
# sonni	5.9444e-06
#
# ninemonth	5.94385e-06
#
# overpow	5.94384e-06
#
# halfway	5.92967e-06
#
# cerullo	5.91253e-06
#
# discriminatori	5.89931e-06
#
# hrb	5.88996e-06
#
# bathroom	5.87731e-06
#
# unwant	5.87313e-06
#
# belmont	5.86516e-06
#
# midatl	5.85064e-06
#
# ballet	5.84981e-06
#
# kin	5.84152e-06
#
# lauderd	5.84123e-06
#
# motel	5.83403e-06
#
# schneidman	5.82323e-06
#
# plaincloth	5.82282e-06
#
# burgu	5.8175e-06
#
# donna	5.8169e-06
#
# platoon	5.8144e-06
#
# ulster	5.80379e-06
#
# roth	5.77862e-06
#
# hoover	5.77754e-06
#
# documentari	5.77733e-06
#
# jessica	5.77704e-06
#
# clint	5.7523e-06
#
# joke	5.73099e-06
#
# iason	5.72475e-06
#
# prensa	5.709e-06
#
# peoria	5.70649e-06
#
# fastfood	5.70121e-06
#
# harwood	5.6988e-06
#
# fantast	5.69631e-06
#
# antismok	5.69046e-06
#
# mccown	5.67562e-06
#
# vandenberg	5.66339e-06
#
# gurski	5.66181e-06
#
# sherri	5.64036e-06
#
# provoc	5.62188e-06
#
# blanchard	5.61795e-06
#
# waren	5.60757e-06
#
# cult	5.59819e-06
#
# shedd	5.58773e-06
#
# kimberli	5.57766e-06
#
# panhandl	5.57172e-06
#
# mistakenli	5.57072e-06
#
# flour	5.57021e-06
#
# overrul	5.56752e-06
#
# verifi	5.55518e-06
#
# chia	5.5403e-06
#
# slope	5.52284e-06
#
# secord	5.51722e-06
#
# dickey	5.50553e-06
#
# airspac	5.4936e-06
#
# sula	5.49194e-06
#
# morgenstern	5.48978e-06
#
# peach	5.48493e-06
#
# scratch	5.47367e-06
#
# joey	5.46861e-06
#
# ami	5.45946e-06
#
# wolvovitz	5.45841e-06
#
# auburn	5.45674e-06
#
# calgari	5.4496e-06
#
# fijian	5.42831e-06
#
# lafont	5.42451e-06
#
# fakhri	5.41198e-06
#
# collin	5.38424e-06
#
# bueno	5.38236e-06
#
# bordallo	5.37108e-06
#
# curran	5.36051e-06
#
# sofaer	5.34821e-06
#
# tribl	5.34308e-06
#
# temblor	5.33957e-06
#
# houstoun	5.3371e-06
#
# holli	5.30328e-06
#
# godfath	5.27799e-06
#
# unisi	5.22929e-06
#
# midland	5.22892e-06
#
# pul	5.21862e-06
#
# banca	5.17492e-06
#
# abid	5.17051e-06
#
# lukman	5.16858e-06
#
# traumat	5.16442e-06
#
# repri	5.14673e-06
#
# friction	5.14355e-06
#
# demot	5.13778e-06
#
# sigmond	5.13375e-06
#
# batter	5.12393e-06
#
# glantz	5.11376e-06
#
# shipbuild	5.10633e-06
#
# newsprint	5.07781e-06
#
# paycheck	5.07732e-06
#
# duo	5.07539e-06
#
# claremont	5.07452e-06
#
# disapprov	5.06378e-06
#
# baggag	5.05233e-06
#
# unexpectedli	5.02817e-06
#
# strauss	5.02278e-06
#
# gill	5.02184e-06
#
# newscast	5.01547e-06
#
# ethiopia	5.00849e-06
#
# burk	4.98719e-06
#
# perfum	4.98312e-06
#
# bronx	4.97408e-06
#
# menendez	4.96434e-06
#
# adjoin	4.96412e-06
#
# hut	4.9634e-06
#
# sevenyear	4.96005e-06
#
# kolb	4.93759e-06
#
# rescuer	4.93661e-06
#
# comb	4.93235e-06
#
# volvo	4.9313e-06
#
# refrig	4.92497e-06
#
# biom	4.91112e-06
#
# erod	4.9108e-06
#
# dudycz	4.91062e-06
#
# hick	4.89873e-06
#
# oswald	4.89692e-06
#
# brigg	4.86222e-06
#
# rajneesh	4.86086e-06
#
# bridesmaid	4.85342e-06
#
# insan	4.84668e-06
#
# wie	4.84551e-06
#
# pakistani	4.83668e-06
#
# taft	4.82959e-06
#
# cutter	4.81499e-06
#
# induc	4.78844e-06
#
# freelanc	4.76797e-06
#
# sweeten	4.7478e-06
#
# cherri	4.70603e-06
#
# loweri	4.70029e-06
#
# intersect	4.69717e-06
#
# elliott	4.68593e-06
#
# benedict	4.67261e-06
#
# teeley	4.66124e-06
#
# asylumseek	4.64536e-06
#
# allmal	4.63667e-06
#
# ochoa	4.61837e-06
#
# lip	4.60478e-06
#
# manual	4.60247e-06
#
# contributor	4.60083e-06
#
# monieson	4.5916e-06
#
# dalai	4.59097e-06
#
# cleric	4.56536e-06
#
# budapest	4.54551e-06
#
# overcrowd	4.53999e-06
#
# azcona	4.53213e-06
#
# fournier	4.51991e-06
#
# diller	4.47756e-06
#
# debra	4.47471e-06
#
# slack	4.47338e-06
#
# kenner	4.46766e-06
#
# dealership	4.44761e-06
#
# alfredo	4.43794e-06
#
# naomi	4.43499e-06
#
# deic	4.4315e-06
#
# pang	4.40943e-06
#
# credenti	4.36945e-06
#
# seton	4.36109e-06
#
# ceremsak	4.34878e-06
#
# juvenil	4.34829e-06
#
# gourmet	4.32726e-06
#
# fingerprint	4.26528e-06
#
# opt	4.26204e-06
#
# trooper	4.23975e-06
#
# notabl	4.23652e-06
#
# trauma	4.22642e-06
#
# revok	4.19695e-06
#
# firstterm	4.19627e-06
#
# brink	4.18953e-06
#
# swindler	4.18263e-06
#
# barbershop	4.17716e-06
#
# malaysia	4.15045e-06
#
# kolberg	4.13425e-06
#
# eli	4.13098e-06
#
# safeguard	4.11299e-06
#
# laurel	4.0806e-06
#
# roberson	4.07908e-06
#
# girlfriend	4.06243e-06
#
# onefifth	4.03689e-06
#
# engulf	4.03061e-06
#
# seidman	4.01973e-06
#
# quartet	4.01945e-06
#
# betray	4.01648e-06
#
# carolyn	4.00321e-06
#
# deukmejian	3.99046e-06
#
# foreclosur	3.97175e-06
#
# hu	3.96681e-06
#
# twoterm	3.95583e-06
#
# herd	3.94078e-06
#
# exci	3.92722e-06
#
# pill	3.90082e-06
#
# southcentr	3.89494e-06
#
# chadli	3.8685e-06
#
# droughtstricken	3.85434e-06
#
# polk	3.8525e-06
#
# minnick	3.84213e-06
#
# eckstein	3.84067e-06
#
# pekin	3.83773e-06
#
# patrolman	3.81664e-06
#
# gardner	3.79624e-06
#
# sandi	3.74418e-06
#
# museveni	3.74417e-06
#
# lyric	3.74169e-06
#
# harmon	3.71467e-06
#
# threequart	3.68008e-06
#
# moss	3.67393e-06
#
# prom	3.66485e-06
#
# christin	3.65933e-06
#
# carbid	3.63768e-06
#
# seconddegr	3.62254e-06
#
# trenton	3.61916e-06
#
# constabl	3.60916e-06
#
# seidon	3.60489e-06
#
# keef	3.60241e-06
#
# multist	3.59202e-06
#
# rabuka	3.58484e-06
#
# lespinass	3.5716e-06
#
# marcher	3.56364e-06
#
# defraud	3.56317e-06
#
# mock	3.54796e-06
#
# mice	3.54494e-06
#
# doc	3.52845e-06
#
# swaggart	3.51643e-06
#
# tarver	3.48169e-06
#
# guthri	3.47833e-06
#
# puppet	3.46865e-06
#
# palmer	3.44436e-06
#
# easterli	3.4258e-06
#
# directori	3.41905e-06
#
# mear	3.37737e-06
#
# tonka	3.37327e-06
#
# discipl	3.35696e-06
#
# abyss	3.35315e-06
#
# nicotin	3.31211e-06
#
# kopper	3.23646e-06
#
# serbia	3.22478e-06
#
# parri	3.22372e-06
#
# parkinson	3.21256e-06
#
# boyfriend	3.21006e-06
#
# amritsar	3.19773e-06
#
# involuntari	3.19242e-06
#
# everett	3.1884e-06
#
# cruzan	3.18773e-06
#
# bcspehealth	3.16419e-06
#
# syracu	3.10262e-06
#
# essay	3.09566e-06
#
# jacob	3.08481e-06
#
# hedg	3.08185e-06
#
# zieman	3.06394e-06
#
# dylan	2.9902e-06
#
# fdic	2.98523e-06
#
# holderman	2.98292e-06
#
# moistur	2.96444e-06
#
# zubal	2.9462e-06
#
# drake	2.93285e-06
#
# rover	2.93198e-06
#
# serbian	2.93108e-06
#
# lundgren	2.91535e-06
#
# merrel	2.91264e-06
#
# trespass	2.90779e-06
#
# benson	2.90541e-06
#
# jason	2.87173e-06
#
# adver	2.86769e-06
#
# lexington	2.82936e-06
#
# wallenda	2.82445e-06
#
# vocalist	2.80281e-06
#
# bendectin	2.70822e-06
#
# epstein	2.67462e-06
#
# kiesner	2.67077e-06
#
# fores	2.63884e-06
#
# bizarr	2.63333e-06
#
# farley	2.62995e-06
#
# republicbank	2.61944e-06
#
# buckey	2.58477e-06
#
# nih	2.57155e-06
#
# wick	2.54117e-06
#
# lutheran	2.52979e-06
#
# pretrial	2.51159e-06
#
# cuito	2.47951e-06
#
# gunter	2.43624e-06
#
# beazley	2.41707e-06
#
# ehrenhalt	2.38396e-06
#
# milosev	2.38155e-06
#
# grandfath	2.38083e-06
#
# sheehan	2.36398e-06
#
# nosair	2.35406e-06
#
# miranda	2.29812e-06
#
# paulo	2.29563e-06
#
# gillespi	2.26486e-06
#
# ama	2.25219e-06
#
# silverado	2.24991e-06
#
# andi	2.24964e-06
#
# reef	2.24061e-06
#
# playboy	2.20396e-06
#
# gibb	2.17979e-06
#
# bass	2.15196e-06
#
# sibl	2.0865e-06
#
# shadysid	2.06497e-06
#
# modifi	2.06486e-06
#
# beam	2.05461e-06
#
# letterman	2.00369e-06
#
# pomona	1.95438e-06
#
# cebu	1.944e-06
#
# bogu	1.92562e-06
#
# montt	1.92429e-06
#
# ski	1.88482e-06
#
# nadin	1.87965e-06
#
# pedestrian	1.8433e-06
#
# clem	1.80185e-06
#
# bujang	1.78307e-06
#
# pauley	1.77782e-06
#
# et	1.68549e-06
#
# watson	1.68521e-06
#
# erol	1.68092e-06
#
# coma	1.66956e-06
#
# gruber	1.64215e-06
#
# coaster	1.55752e-06
#
# rand	1.55166e-06
#
# lit	1.54946e-06
#
# lama	1.5279e-06
#
# tosh	1.47597e-06
#
# aground	1.45154e-06
#
# alito	1.44362e-06
#
# williamson	1.44014e-06
#
# radakovich	1.43024e-06
#
# smokeless	1.38952e-06
#
# burger	1.38544e-06
#
# bookstor	1.33885e-06
#
# abductor	1.31233e-06
#
# guin	1.25684e-06
#
# revolv	1.24771e-06
#
# bowen	1.20802e-06
#
# conceicao	1.15822e-06
#
# hazelwood	1.13422e-06
#
# ugandan	1.09226e-06
#
# arc	1.04424e-06
#
# documentmatch	1.02508e-06
#
# symchych	1.01284e-06
#
# schulz	1.01085e-06
#
# elliot	9.89313e-07
#
# guida	9.87773e-07
#
# feazel	9.3634e-07
#
# mattox	9.2665e-07
#
# morgu	9.24976e-07
#
# mirecki	8.49422e-07
#
# hast	7.93446e-07
#
# ganyil	7.81718e-07
#
# chelsea	7.1984e-07
#
# busfield	6.56465e-07
#
# depositor	6.24965e-07
#
# hahn	5.89448e-07
#
# cdi	5.8105e-07
#
# glauberman	5.66753e-07
#
# teddi	5.54787e-07
#
# dilorenzo	5.43434e-07
#
# lobban	5.34823e-07
#
# cove	4.64621e-07
#
# clr	4.61918e-07
#
# jeffer	4.56632e-07
#
# dyke	4.54985e-07
#
# hasegawa	4.07994e-07
#
# spoor	2.88726e-07
#
# baugh	2.78135e-07
#
# leek	1.4405e-07
#
# kahan	1.05004e-07
#
# sowan	9.00416e-08
#
# mchaffi	7.36915e-08
#
# gracyalni	1.28813e-08
#
# rn	5.91918e-10
#
# TRUE	0
